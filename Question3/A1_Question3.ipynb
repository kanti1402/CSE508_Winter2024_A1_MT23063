# %% [markdown]
# **Question 3: POSITIONAL INDEX AND PHRASE QUERIES**
#
# ---
#
#
#
# ---

# %% [markdown]
# **DRIVE MOUNTE**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **LIBRARY / PACKAGE**

# %%
import os
import re
import string
import warnings
import pickle
import nltk

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# **INPUT FOLDER**

# %%
directory_path = "/content/drive/MyDrive/text_files/"

# %% [markdown]
# **POSITIONAL INDEX CREATION**

# %%
positional_index = {}

for doc_id in range(1,1000):
    file_path = os.path.join(directory_path, f"file{doc_id}.txt")

    if os.path.exists(file_path):
        with open(file_path, 'r') as file:
            content = file.read()
            terms = content.split()

            for position, term in enumerate(terms, start=1):
                if term not in positional_index:
                    positional_index[term] = {
                        'doc_count': 1,
                        'docs': {doc_id: [position]}
                    }
                else:
                    positional_index[term]['doc_count'] += 1
                    if doc_id not in positional_index[term]['docs']:
                        positional_index[term]['docs'][doc_id] = [position]
                    else:
                        positional_index[term]['docs'][doc_id].append(position)
    else:
        print(f"File file{doc_id}.txt does not exist.")

# %%
for key, value in positional_index.items():
    print(f"{key}: {{\n    'doc_freq': {value['doc_count']},\n    'docs': {value['docs']}\n}}")
# Out:
# Streaming output truncated to the last 5000 lines.
# decision: {
#     'doc_freq': 1,
#     'docs': {680: [7]}
# }
# shelled: {
#     'doc_freq': 1,
#     'docs': {680: [9]}
# }
# 3035: {
#     'doc_freq': 1,
#     'docs': {680: [10]}
# }
# licensed: {
#     'doc_freq': 1,
#     'docs': {680: [14]}
# }
# eat: {
#     'doc_freq': 1,
#     'docs': {680: [17]}
# }
# knocking: {
#     'doc_freq': 1,
#     'docs': {680: [23]}
# }
# auratone: {
#     'doc_freq': 1,
#     'docs': {681: [7]}
# }
# ilouds: {
#     'doc_freq': 1,
#     'docs': {681: [15]}
# }
# steroids: {
#     'doc_freq': 1,
#     'docs': {681: [26]}
# }
# pairing: {
#     'doc_freq': 1,
#     'docs': {681: [27]}
# }
# inboard: {
#     'doc_freq': 1,
#     'docs': {681: [28]}
# }
# matched: {
#     'doc_freq': 2,
#     'docs': {681: [30], 835: [68]}
# }
# loudly: {
#     'doc_freq': 1,
#     'docs': {681: [46]}
# }
# girlfriend: {
#     'doc_freq': 1,
#     'docs': {681: [58]}
# }
# transportation: {
#     'doc_freq': 1,
#     'docs': {682: [7]}
# }
# keyboardssustain: {
#     'doc_freq': 1,
#     'docs': {684: [39]}
# }
# workaround: {
#     'doc_freq': 1,
#     'docs': {684: [53]}
# }
# tiling: {
#     'doc_freq': 1,
#     'docs': {684: [59]}
# }
# duct: {
#     'doc_freq': 1,
#     'docs': {684: [63]}
# }
# prep: {
#     'doc_freq': 1,
#     'docs': {685: [9]}
# }
# sat: {
#     'doc_freq': 2,
#     'docs': {686: [12], 915: [26]}
# }
# gooseneck: {
#     'doc_freq': 6,
#     'docs': {686: [27], 716: [67], 949: [31, 67], 975: [20, 30]}
# }
# falls: {
#     'doc_freq': 1,
#     'docs': {686: [35]}
# }
# dp1: {
#     'doc_freq': 1,
#     'docs': {687: [3]}
# }
# noisy: {
#     'doc_freq': 5,
#     'docs': {687: [7], 728: [32], 739: [25], 760: [71], 927: [13]}
# }
# daisychain: {
#     'doc_freq': 1,
#     'docs': {687: [8]}
# }
# dl4: {
#     'doc_freq': 1,
#     'docs': {687: [16]}
# }
# reverse: {
#     'doc_freq': 1,
#     'docs': {687: [17]}
# }
# interruptions: {
#     'doc_freq': 1,
#     'docs': {687: [23]}
# }
# failures: {
#     'doc_freq': 1,
#     'docs': {687: [25]}
# }
# readingresearch: {
#     'doc_freq': 1,
#     'docs': {687: [28]}
# }
# independent: {
#     'doc_freq': 1,
#     'docs': {687: [30]}
# }
# share: {
#     'doc_freq': 1,
#     'docs': {687: [32]}
# }
# electrician: {
#     'doc_freq': 1,
#     'docs': {687: [36]}
# }
# mitchell: {
#     'doc_freq': 1,
#     'docs': {688: [3]}
# }
# isa: {
#     'doc_freq': 1,
#     'docs': {689: [2]}
# }
# seasonal: {
#     'doc_freq': 1,
#     'docs': {689: [6]}
# }
# chair: {
#     'doc_freq': 4,
#     'docs': {689: [23], 766: [6, 32, 37]}
# }
# blends: {
#     'doc_freq': 1,
#     'docs': {690: [1]}
# }
# tonearm: {
#     'doc_freq': 1,
#     'docs': {690: [4]}
# }
# 4g: {
#     'doc_freq': 1,
#     'docs': {690: [6]}
# }
# conjunction: {
#     'doc_freq': 1,
#     'docs': {690: [11]}
# }
# ortofon: {
#     'doc_freq': 2,
#     'docs': {690: [12, 27]}
# }
# 2m: {
#     'doc_freq': 1,
#     'docs': {690: [13]}
# }
# 1200mk2: {
#     'doc_freq': 1,
#     'docs': {690: [15]}
# }
# concorde: {
#     'doc_freq': 1,
#     'docs': {690: [25]}
# }
# 5mv: {
#     'doc_freq': 1,
#     'docs': {690: [31]}
# }
# whereas: {
#     'doc_freq': 1,
#     'docs': {690: [38]}
# }
# cartridgestylus: {
#     'doc_freq': 1,
#     'docs': {690: [40]}
# }
# 6db: {
#     'doc_freq': 1,
#     'docs': {690: [42]}
# }
# stylii: {
#     'doc_freq': 1,
#     'docs': {690: [49]}
# }
# headshell: {
#     'doc_freq': 2,
#     'docs': {690: [50, 52]}
# }
# altogether: {
#     'doc_freq': 2,
#     'docs': {690: [53], 930: [27]}
# }
# 2007: {
#     'doc_freq': 1,
#     'docs': {691: [2]}
# }
# 07: {
#     'doc_freq': 1,
#     'docs': {691: [20]}
# }
# ostracized: {
#     'doc_freq': 1,
#     'docs': {691: [26]}
# }
# commemorate: {
#     'doc_freq': 1,
#     'docs': {691: [38]}
# }
# image: {
#     'doc_freq': 5,
#     'docs': {691: [44], 719: [75], 784: [47], 889: [23], 912: [50]}
# }
# 1977: {
#     'doc_freq': 1,
#     'docs': {691: [45]}
# }
# musicmaster: {
#     'doc_freq': 1,
#     'docs': {691: [47]}
# }
# plasticky: {
#     'doc_freq': 1,
#     'docs': {692: [11]}
# }
# teeth: {
#     'doc_freq': 1,
#     'docs': {692: [22]}
# }
# obrien: {
#     'doc_freq': 1,
#     'docs': {692: [24]}
# }
# richard: {
#     'doc_freq': 1,
#     'docs': {692: [26]}
# }
# hawkins: {
#     'doc_freq': 1,
#     'docs': {692: [27]}
# }
# robert: {
#     'doc_freq': 3,
#     'docs': {692: [38], 718: [45], 936: [3]}
# }
# hah: {
#     'doc_freq': 1,
#     'docs': {692: [39]}
# }
# internet: {
#     'doc_freq': 1,
#     'docs': {697: [10]}
# }
# telosone: {
#     'doc_freq': 1,
#     'docs': {697: [25]}
# }
# indicating: {
#     'doc_freq': 1,
#     'docs': {698: [17]}
# }
# occured: {
#     'doc_freq': 1,
#     'docs': {698: [19]}
# }
# fur: {
#     'doc_freq': 1,
#     'docs': {699: [13]}
# }
# lining: {
#     'doc_freq': 3,
#     'docs': {699: [14], 873: [5], 915: [8]}
# }
# exterior: {
#     'doc_freq': 1,
#     'docs': {699: [17]}
# }
# beaters: {
#     'doc_freq': 1,
#     'docs': {699: [20]}
# }
# divider: {
#     'doc_freq': 1,
#     'docs': {699: [42]}
# }
# replacements: {
#     'doc_freq': 2,
#     'docs': {700: [4], 855: [13]}
# }
# guitalele: {
#     'doc_freq': 1,
#     'docs': {700: [6]}
# }
# gl1: {
#     'doc_freq': 2,
#     'docs': {700: [7, 42]}
# }
# gauged: {
#     'doc_freq': 2,
#     'docs': {700: [9], 987: [7]}
# }
# ee: {
#     'doc_freq': 1,
#     'docs': {700: [10]}
# }
# aa: {
#     'doc_freq': 2,
#     'docs': {700: [12], 769: [35]}
# }
# dummy: {
#     'doc_freq': 1,
#     'docs': {700: [31]}
# }
# diligence: {
#     'doc_freq': 1,
#     'docs': {700: [36]}
# }
# recommendation: {
#     'doc_freq': 2,
#     'docs': {700: [38], 819: [75]}
# }
# fire: {
#     'doc_freq': 3,
#     'docs': {701: [11, 41], 839: [16]}
# }
# hazard: {
#     'doc_freq': 1,
#     'docs': {701: [12]}
# }
# rattling: {
#     'doc_freq': 1,
#     'docs': {701: [27]}
# }
# opene: {
#     'doc_freq': 1,
#     'docs': {701: [29]}
# }
# circuitry: {
#     'doc_freq': 1,
#     'docs': {701: [34]}
# }
# internal: {
#     'doc_freq': 2,
#     'docs': {701: [38], 975: [34]}
# }
# circuit: {
#     'doc_freq': 1,
#     'docs': {701: [40]}
# }
# wondering: {
#     'doc_freq': 1,
#     'docs': {701: [50]}
# }
# bare: {
#     'doc_freq': 2,
#     'docs': {702: [3], 790: [11]}
# }
# nails: {
#     'doc_freq': 2,
#     'docs': {702: [6], 994: [48]}
# }
# mits: {
#     'doc_freq': 1,
#     'docs': {702: [15]}
# }
# stops: {
#     'doc_freq': 1,
#     'docs': {703: [27]}
# }
# erases: {
#     'doc_freq': 1,
#     'docs': {703: [29]}
# }
# momentary: {
#     'doc_freq': 2,
#     'docs': {703: [34, 45]}
# }
# nonlatching: {
#     'doc_freq': 1,
#     'docs': {703: [35]}
# }
# oneshot: {
#     'doc_freq': 1,
#     'docs': {703: [43]}
# }
# clicktype: {
#     'doc_freq': 1,
#     'docs': {703: [44]}
# }
# operation: {
#     'doc_freq': 3,
#     'docs': {703: [51, 61, 94]}
# }
# explains: {
#     'doc_freq': 1,
#     'docs': {703: [58]}
# }
# footswtich: {
#     'doc_freq': 1,
#     'docs': {703: [60]}
# }
# follows: {
#     'doc_freq': 1,
#     'docs': {703: [62]}
# }
# do: {
#     'doc_freq': 1,
#     'docs': {703: [63]}
# }
# recordingoverdubbingplayback: {
#     'doc_freq': 1,
#     'docs': {703: [69]}
# }
# erase: {
#     'doc_freq': 2,
#     'docs': {703: [73, 80]}
# }
# phrase: {
#     'doc_freq': 2,
#     'docs': {703: [74, 81]}
# }
# the: {
#     'doc_freq': 1,
#     'docs': {703: [88]}
# }
# goodthe: {
#     'doc_freq': 1,
#     'docs': {703: [89]}
# }
# reply: {
#     'doc_freq': 1,
#     'docs': {703: [109]}
# }
# email: {
#     'doc_freq': 1,
#     'docs': {703: [110]}
# }
# dept: {
#     'doc_freq': 2,
#     'docs': {703: [113], 742: [75]}
# }
# thumping: {
#     'doc_freq': 1,
#     'docs': {706: [7]}
# }
# rounds: {
#     'doc_freq': 1,
#     'docs': {706: [10]}
# }
# sheriff: {
#     'doc_freq': 1,
#     'docs': {706: [16]}
# }
# audiosavings: {
#     'doc_freq': 1,
#     'docs': {706: [25]}
# }
# floored: {
#     'doc_freq': 1,
#     'docs': {706: [26]}
# }
# ship: {
#     'doc_freq': 1,
#     'docs': {706: [28]}
# }
# doorstep: {
#     'doc_freq': 1,
#     'docs': {706: [32]}
# }
# rockville: {
#     'doc_freq': 1,
#     'docs': {706: [44]}
# }
# kudos: {
#     'doc_freq': 1,
#     'docs': {706: [55]}
# }
# everybody: {
#     'doc_freq': 1,
#     'docs': {707: [2]}
# }
# 48v: {
#     'doc_freq': 1,
#     'docs': {707: [13]}
# }
# floureon: {
#     'doc_freq': 1,
#     'docs': {707: [17]}
# }
# flashing: {
#     'doc_freq': 1,
#     'docs': {708: [5]}
# }
# pazaz: {
#     'doc_freq': 1,
#     'docs': {708: [11]}
# }
# dimmed: {
#     'doc_freq': 1,
#     'docs': {708: [17]}
# }
# lx5: {
#     'doc_freq': 1,
#     'docs': {708: [19]}
# }
# flashes: {
#     'doc_freq': 1,
#     'docs': {708: [25]}
# }
# dubstep: {
#     'doc_freq': 1,
#     'docs': {708: [37]}
# }
# alternated: {
#     'doc_freq': 1,
#     'docs': {708: [45]}
# }
# climb: {
#     'doc_freq': 1,
#     'docs': {708: [47]}
# }
# flashed: {
#     'doc_freq': 1,
#     'docs': {708: [48]}
# }
# unison: {
#     'doc_freq': 1,
#     'docs': {708: [49]}
# }
# circle: {
#     'doc_freq': 3,
#     'docs': {708: [62], 747: [22], 861: [42]}
# }
# vendor: {
#     'doc_freq': 2,
#     'docs': {708: [77], 778: [13]}
# }
# restocking: {
#     'doc_freq': 1,
#     'docs': {708: [84]}
# }
# heil: {
#     'doc_freq': 1,
#     'docs': {709: [2]}
# }
# pr: {
#     'doc_freq': 1,
#     'docs': {709: [3]}
# }
# utilize: {
#     'doc_freq': 1,
#     'docs': {709: [9]}
# }
# pr40: {
#     'doc_freq': 1,
#     'docs': {709: [12]}
# }
# 3pack: {
#     'doc_freq': 1,
#     'docs': {710: [4]}
# }
# knocked: {
#     'doc_freq': 1,
#     'docs': {710: [15]}
# }
# righted: {
#     'doc_freq': 1,
#     'docs': {710: [17]}
# }
# impressively: {
#     'doc_freq': 1,
#     'docs': {710: [18]}
# }
# dash: {
#     'doc_freq': 1,
#     'docs': {711: [5]}
# }
# eleven: {
#     'doc_freq': 1,
#     'docs': {711: [19]}
# }
# fractal: {
#     'doc_freq': 1,
#     'docs': {711: [21]}
# }
# axefxii: {
#     'doc_freq': 1,
#     'docs': {711: [24]}
# }
# userloowood2: {
#     'doc_freq': 1,
#     'docs': {711: [27]}
# }
# google: {
#     'doc_freq': 1,
#     'docs': {711: [28]}
# }
# loowood: {
#     'doc_freq': 1,
#     'docs': {711: [29]}
# }
# pleasure: {
#     'doc_freq': 1,
#     'docs': {712: [8]}
# }
# fooling: {
#     'doc_freq': 1,
#     'docs': {712: [26]}
# }
# intensity: {
#     'doc_freq': 1,
#     'docs': {712: [64]}
# }
# pushing: {
#     'doc_freq': 1,
#     'docs': {712: [77]}
# }
# thrash: {
#     'doc_freq': 1,
#     'docs': {712: [83]}
# }
# selector: {
#     'doc_freq': 1,
#     'docs': {714: [9]}
# }
# backplates: {
#     'doc_freq': 1,
#     'docs': {714: [22]}
# }
# 1020: {
#     'doc_freq': 1,
#     'docs': {714: [32]}
# }
# vibrant: {
#     'doc_freq': 1,
#     'docs': {715: [17]}
# }
# skrims: {
#     'doc_freq': 2,
#     'docs': {715: [32], 901: [1]}
# }
# c01ucw: {
#     'doc_freq': 1,
#     'docs': {716: [8]}
# }
# desktop: {
#     'doc_freq': 1,
#     'docs': {716: [18]}
# }
# weighing: {
#     'doc_freq': 1,
#     'docs': {716: [20]}
# }
# lean: {
#     'doc_freq': 1,
#     'docs': {716: [27]}
# }
# till: {
#     'doc_freq': 3,
#     'docs': {716: [36], 752: [38], 876: [4]}
# }
# psa1: {
#     'doc_freq': 1,
#     'docs': {716: [39]}
# }
# dragonpad: {
#     'doc_freq': 1,
#     'docs': {716: [55]}
# }
# blaming: {
#     'doc_freq': 1,
#     'docs': {716: [88]}
# }
# pointing: {
#     'doc_freq': 1,
#     'docs': {716: [94]}
# }
# faced: {
#     'doc_freq': 1,
#     'docs': {716: [96]}
# }
# cs: {
#     'doc_freq': 2,
#     'docs': {718: [4], 936: [2]}
# }
# requirements: {
#     'doc_freq': 1,
#     'docs': {718: [10]}
# }
# strymon: {
#     'doc_freq': 1,
#     'docs': {718: [11]}
# }
# sky: {
#     'doc_freq': 1,
#     'docs': {718: [13]}
# }
# eventide: {
#     'doc_freq': 1,
#     'docs': {718: [14]}
# }
# timefactor: {
#     'doc_freq': 1,
#     'docs': {718: [15]}
# }
# digtech: {
#     'doc_freq': 1,
#     'docs': {718: [16]}
# }
# v4: {
#     'doc_freq': 1,
#     'docs': {718: [18]}
# }
# 18vdc: {
#     'doc_freq': 1,
#     'docs': {718: [22]}
# }
# 9vdc: {
#     'doc_freq': 1,
#     'docs': {718: [25]}
# }
# truetone: {
#     'doc_freq': 1,
#     'docs': {718: [27]}
# }
# v189: {
#     'doc_freq': 1,
#     'docs': {718: [28]}
# }
# converter: {
#     'doc_freq': 1,
#     'docs': {718: [29]}
# }
# capability: {
#     'doc_freq': 1,
#     'docs': {718: [30]}
# }
# ports: {
#     'doc_freq': 2,
#     'docs': {718: [33], 765: [39]}
# }
# novo: {
#     'doc_freq': 2,
#     'docs': {718: [39, 70]}
# }
# 32: {
#     'doc_freq': 2,
#     'docs': {718: [40, 71]}
# }
# cs12: {
#     'doc_freq': 2,
#     'docs': {718: [55, 66]}
# }
# partial: {
#     'doc_freq': 1,
#     'docs': {718: [72]}
# }
# studying: {
#     'doc_freq': 1,
#     'docs': {719: [2]}
# }
# mike: {
#     'doc_freq': 4,
#     'docs': {719: [10, 21], 813: [21], 917: [5]}
# }
# atr: {
#     'doc_freq': 1,
#     'docs': {719: [16]}
# }
# 2100: {
#     'doc_freq': 3,
#     'docs': {719: [17, 18, 56]}
# }
# indicates: {
#     'doc_freq': 1,
#     'docs': {719: [19]}
# }
# 51mm: {
#     'doc_freq': 1,
#     'docs': {719: [20]}
# }
# trunk: {
#     'doc_freq': 2,
#     'docs': {719: [23], 746: [20]}
# }
# researching: {
#     'doc_freq': 1,
#     'docs': {719: [30]}
# }
# pipe: {
#     'doc_freq': 2,
#     'docs': {719: [37, 42]}
# }
# insulation: {
#     'doc_freq': 1,
#     'docs': {719: [38]}
# }
# pvc: {
#     'doc_freq': 1,
#     'docs': {719: [41]}
# }
# readily: {
#     'doc_freq': 1,
#     'docs': {719: [45]}
# }
# inconsistencies: {
#     'doc_freq': 1,
#     'docs': {720: [7]}
# }
# affect: {
#     'doc_freq': 1,
#     'docs': {720: [20]}
# }
# protractor: {
#     'doc_freq': 1,
#     'docs': {720: [27]}
# }
# channellocks: {
#     'doc_freq': 1,
#     'docs': {720: [41]}
# }
# stained: {
#     'doc_freq': 3,
#     'docs': {720: [54], 770: [72], 805: [15]}
# }
# pine: {
#     'doc_freq': 1,
#     'docs': {720: [55]}
# }
# newlymanufactured: {
#     'doc_freq': 1,
#     'docs': {721: [19]}
# }
# 97: {
#     'doc_freq': 1,
#     'docs': {721: [27]}
# }
# contrast: {
#     'doc_freq': 1,
#     'docs': {721: [42]}
# }
# bust: {
#     'doc_freq': 1,
#     'docs': {721: [46]}
# }
# calipers: {
#     'doc_freq': 1,
#     'docs': {721: [47]}
# }
# giggles: {
#     'doc_freq': 1,
#     'docs': {721: [57]}
# }
# peeling: {
#     'doc_freq': 3,
#     'docs': {722: [8], 777: [41], 861: [24]}
# }
# discribed: {
#     'doc_freq': 1,
#     'docs': {724: [2]}
# }
# gorgeous: {
#     'doc_freq': 2,
#     'docs': {725: [5], 781: [28]}
# }
# twea: {
#     'doc_freq': 1,
#     'docs': {725: [11]}
# }
# axes: {
#     'doc_freq': 1,
#     'docs': {725: [30]}
# }
# screams: {
#     'doc_freq': 1,
#     'docs': {725: [34]}
# }
# pinkies: {
#     'doc_freq': 1,
#     'docs': {725: [38]}
# }
# 27: {
#     'doc_freq': 1,
#     'docs': {726: [15]}
# }
# roots: {
#     'doc_freq': 1,
#     'docs': {727: [21]}
# }
# grunge: {
#     'doc_freq': 2,
#     'docs': {727: [23], 747: [16]}
# }
# dc40: {
#     'doc_freq': 1,
#     'docs': {727: [32]}
# }
# unhappy: {
#     'doc_freq': 1,
#     'docs': {727: [34]}
# }
# punched: {
#     'doc_freq': 1,
#     'docs': {728: [27]}
# }
# drawer: {
#     'doc_freq': 3,
#     'docs': {728: [39, 53], 735: [4]}
# }
# random: {
#     'doc_freq': 1,
#     'docs': {728: [42]}
# }
# bummed: {
#     'doc_freq': 1,
#     'docs': {728: [48]}
# }
# exceeded: {
#     'doc_freq': 1,
#     'docs': {730: [2]}
# }
# amber: {
#     'doc_freq': 2,
#     'docs': {730: [4], 895: [17]}
# }
# reccomend: {
#     'doc_freq': 1,
#     'docs': {730: [16]}
# }
# lazarro: {
#     'doc_freq': 2,
#     'docs': {731: [5, 32]}
# }
# cares: {
#     'doc_freq': 1,
#     'docs': {731: [6]}
# }
# saxophone: {
#     'doc_freq': 4,
#     'docs': {731: [7, 47, 54], 766: [8]}
# }
# everyday: {
#     'doc_freq': 1,
#     'docs': {731: [18]}
# }
# clark: {
#     'doc_freq': 1,
#     'docs': {731: [21]}
# }
# forbes: {
#     'doc_freq': 1,
#     'docs': {731: [22]}
# }
# debut: {
#     'doc_freq': 1,
#     'docs': {731: [23]}
# }
# reeds: {
#     'doc_freq': 3,
#     'docs': {731: [25, 33, 41]}
# }
# select: {
#     'doc_freq': 1,
#     'docs': {731: [39]}
# }
# 3s: {
#     'doc_freq': 1,
#     'docs': {731: [42]}
# }
# hundreds: {
#     'doc_freq': 1,
#     'docs': {731: [60]}
# }
# tha: {
#     'doc_freq': 1,
#     'docs': {732: [1]}
# }
# ccbhc: {
#     'doc_freq': 1,
#     'docs': {733: [2]}
# }
# vi: {
#     'doc_freq': 3,
#     'docs': {733: [7, 21, 64]}
# }
# rigors: {
#     'doc_freq': 1,
#     'docs': {733: [13]}
# }
# touring: {
#     'doc_freq': 1,
#     'docs': {733: [14]}
# }
# hardshell: {
#     'doc_freq': 1,
#     'docs': {733: [18]}
# }
# gem: {
#     'doc_freq': 1,
#     'docs': {733: [24]}
# }
# sizing: {
#     'doc_freq': 3,
#     'docs': {733: [38], 745: [25], 912: [69]}
# }
# floppy: {
#     'doc_freq': 1,
#     'docs': {733: [52]}
# }
# lack: {
#     'doc_freq': 1,
#     'docs': {733: [55]}
# }
# reinforcement: {
#     'doc_freq': 1,
#     'docs': {733: [56]}
# }
# owner: {
#     'doc_freq': 3,
#     'docs': {733: [65], 901: [13], 937: [84]}
# }
# takamine: {
#     'doc_freq': 1,
#     'docs': {734: [14]}
# }
# pd5: {
#     'doc_freq': 1,
#     'docs': {734: [15]}
# }
# fiddle: {
#     'doc_freq': 1,
#     'docs': {736: [7]}
# }
# nearsighted: {
#     'doc_freq': 1,
#     'docs': {736: [43]}
# }
# drunkard: {
#     'doc_freq': 1,
#     'docs': {736: [44]}
# }
# offcenter: {
#     'doc_freq': 1,
#     'docs': {736: [46]}
# }
# weaken: {
#     'doc_freq': 1,
#     'docs': {736: [48]}
# }
# arte: {
#     'doc_freq': 1,
#     'docs': {736: [56]}
# }
# wobbly: {
#     'doc_freq': 2,
#     'docs': {737: [5], 933: [4]}
# }
# wilkinson: {
#     'doc_freq': 1,
#     'docs': {737: [8]}
# }
# v100pgm: {
#     'doc_freq': 1,
#     'docs': {737: [11]}
# }
# icon: {
#     'doc_freq': 1,
#     'docs': {737: [12]}
# }
# greeny: {
#     'doc_freq': 1,
#     'docs': {737: [15]}
# }
# 10mm: {
#     'doc_freq': 1,
#     'docs': {737: [19]}
# }
# 9mm: {
#     'doc_freq': 1,
#     'docs': {737: [23]}
# }
# dull: {
#     'doc_freq': 2,
#     'docs': {737: [32], 785: [12]}
# }
# field: {
#     'doc_freq': 1,
#     'docs': {738: [8]}
# }
# effectively: {
#     'doc_freq': 2,
#     'docs': {738: [14], 770: [49]}
# }
# sturdily: {
#     'doc_freq': 3,
#     'docs': {738: [19], 805: [47], 835: [8]}
# }
# ntg2: {
#     'doc_freq': 1,
#     'docs': {738: [22]}
# }
# tipping: {
#     'doc_freq': 1,
#     'docs': {738: [26]}
# }
# clipping: {
#     'doc_freq': 1,
#     'docs': {738: [27]}
# }
# shotgun: {
#     'doc_freq': 1,
#     'docs': {738: [32]}
# }
# precarious: {
#     'doc_freq': 1,
#     'docs': {738: [34]}
# }
# screwon: {
#     'doc_freq': 1,
#     'docs': {738: [40]}
# }
# lowcost: {
#     'doc_freq': 1,
#     'docs': {739: [2]}
# }
# filler: {
#     'doc_freq': 1,
#     'docs': {739: [8]}
# }
# shadows: {
#     'doc_freq': 1,
#     'docs': {739: [11]}
# }
# flickering: {
#     'doc_freq': 2,
#     'docs': {739: [19, 28]}
# }
# eliminate: {
#     'doc_freq': 1,
#     'docs': {739: [27]}
# }
# gimmit: {
#     'doc_freq': 1,
#     'docs': {740: [1]}
# }
# daughters: {
#     'doc_freq': 1,
#     'docs': {741: [2]}
# }
# luke: {
#     'doc_freq': 1,
#     'docs': {741: [10]}
# }
# birthday: {
#     'doc_freq': 3,
#     'docs': {741: [20], 935: [56], 968: [9]}
# }
# mass: {
#     'doc_freq': 1,
#     'docs': {741: [31]}
# }
# stellar: {
#     'doc_freq': 1,
#     'docs': {741: [36]}
# }
# young: {
#     'doc_freq': 2,
#     'docs': {741: [44], 770: [59]}
# }
# nuts: {
#     'doc_freq': 3,
#     'docs': {741: [52], 744: [46], 764: [50]}
# }
# arrives: {
#     'doc_freq': 1,
#     'docs': {741: [54]}
# }
# docked: {
#     'doc_freq': 1,
#     'docs': {741: [55]}
# }
# dislike: {
#     'doc_freq': 1,
#     'docs': {741: [59]}
# }
# mugig: {
#     'doc_freq': 1,
#     'docs': {742: [2]}
# }
# musedo: {
#     'doc_freq': 2,
#     'docs': {742: [6, 11]}
# }
# assumption: {
#     'doc_freq': 1,
#     'docs': {742: [17]}
# }
# massproduced: {
#     'doc_freq': 1,
#     'docs': {742: [20]}
# }
# logos: {
#     'doc_freq': 1,
#     'docs': {742: [26]}
# }
# enclosed: {
#     'doc_freq': 1,
#     'docs': {742: [33]}
# }
# 2day: {
#     'doc_freq': 1,
#     'docs': {742: [43]}
# }
# tm50bk: {
#     'doc_freq': 2,
#     'docs': {742: [56, 87]}
# }
# lying: {
#     'doc_freq': 1,
#     'docs': {742: [66]}
# }
# donate: {
#     'doc_freq': 1,
#     'docs': {742: [71]}
# }
# wincluded: {
#     'doc_freq': 1,
#     'docs': {742: [78]}
# }
# clipon: {
#     'doc_freq': 1,
#     'docs': {742: [79]}
# }
# co2crea: {
#     'doc_freq': 1,
#     'docs': {742: [83]}
# }
# b01f8imxvc: {
#     'doc_freq': 1,
#     'docs': {742: [90]}
# }
# cc: {
#     'doc_freq': 1,
#     'docs': {742: [99]}
# }
# memberreviewer: {
#     'doc_freq': 1,
#     'docs': {742: [102]}
# }
# downright: {
#     'doc_freq': 1,
#     'docs': {743: [3]}
# }
# luxurious: {
#     'doc_freq': 1,
#     'docs': {743: [4]}
# }
# hummingbirds: {
#     'doc_freq': 1,
#     'docs': {743: [11]}
# }
# siii: {
#     'doc_freq': 1,
#     'docs': {743: [26]}
# }
# craft: {
#     'doc_freq': 1,
#     'docs': {744: [5]}
# }
# weekend: {
#     'doc_freq': 1,
#     'docs': {744: [7]}
# }
# tumers: {
#     'doc_freq': 1,
#     'docs': {744: [10]}
# }
# pliers: {
#     'doc_freq': 1,
#     'docs': {744: [23]}
# }
# mlthe: {
#     'doc_freq': 1,
#     'docs': {744: [26]}
# }
# shpuld: {
#     'doc_freq': 1,
#     'docs': {744: [32]}
# }
# hqve: {
#     'doc_freq': 1,
#     'docs': {744: [34]}
# }
# cbgs: {
#     'doc_freq': 1,
#     'docs': {744: [56]}
# }
# squeezes: {
#     'doc_freq': 1,
#     'docs': {745: [22]}
# }
# pinky: {
#     'doc_freq': 1,
#     'docs': {745: [24]}
# }
# question: {
#     'doc_freq': 1,
#     'docs': {746: [1]}
# }
# squished: {
#     'doc_freq': 1,
#     'docs': {746: [8]}
# }
# pile: {
#     'doc_freq': 2,
#     'docs': {746: [22], 836: [13]}
# }
# chances: {
#     'doc_freq': 1,
#     'docs': {746: [28]}
# }
# gigbag: {
#     'doc_freq': 3,
#     'docs': {746: [45, 59, 61]}
# }
# goto: {
#     'doc_freq': 1,
#     'docs': {746: [58]}
# }
# getter: {
#     'doc_freq': 1,
#     'docs': {746: [65]}
# }
# fabtastic: {
#     'doc_freq': 1,
#     'docs': {747: [1]}
# }
# goodness: {
#     'doc_freq': 1,
#     'docs': {747: [6]}
# }
# distored: {
#     'doc_freq': 1,
#     'docs': {747: [11]}
# }
# unaudible: {
#     'doc_freq': 1,
#     'docs': {747: [15]}
# }
# ruckus: {
#     'doc_freq': 1,
#     'docs': {747: [17]}
# }
# perceived: {
#     'doc_freq': 1,
#     'docs': {747: [19]}
# }
# rhombus: {
#     'doc_freq': 1,
#     'docs': {747: [23]}
# }
# everest: {
#     'doc_freq': 1,
#     'docs': {748: [4]}
# }
# morning: {
#     'doc_freq': 2,
#     'docs': {748: [28], 871: [39]}
# }
# rosined: {
#     'doc_freq': 1,
#     'docs': {748: [35]}
# }
# resulted: {
#     'doc_freq': 1,
#     'docs': {748: [41]}
# }
# helicore: {
#     'doc_freq': 1,
#     'docs': {748: [49]}
# }
# bed: {
#     'doc_freq': 3,
#     'docs': {749: [24], 793: [11], 849: [23]}
# }
# sleep: {
#     'doc_freq': 1,
#     'docs': {749: [28]}
# }
# stratocasters: {
#     'doc_freq': 1,
#     'docs': {749: [41]}
# }
# stamps: {
#     'doc_freq': 1,
#     'docs': {750: [6]}
# }
# unfamiliar: {
#     'doc_freq': 1,
#     'docs': {750: [12]}
# }
# ligatures: {
#     'doc_freq': 1,
#     'docs': {752: [1]}
# }
# students: {
#     'doc_freq': 1,
#     'docs': {752: [5]}
# }
# scerouse: {
#     'doc_freq': 1,
#     'docs': {752: [10]}
# }
# cleanst: {
#     'doc_freq': 2,
#     'docs': {752: [16, 31]}
# }
# scent: {
#     'doc_freq': 1,
#     'docs': {752: [23]}
# }
# xmas: {
#     'doc_freq': 1,
#     'docs': {752: [27]}
# }
# wannted: {
#     'doc_freq': 1,
#     'docs': {752: [29]}
# }
# pickgaurd: {
#     'doc_freq': 1,
#     'docs': {753: [6]}
# }
# drimel: {
#     'doc_freq': 1,
#     'docs': {753: [21]}
# }
# gaps: {
#     'doc_freq': 1,
#     'docs': {753: [27]}
# }
# hbs: {
#     'doc_freq': 2,
#     'docs': {756: [17, 35]}
# }
# grungefuzz: {
#     'doc_freq': 2,
#     'docs': {756: [25, 38]}
# }
# hbseach: {
#     'doc_freq': 1,
#     'docs': {756: [32]}
# }
# catalina: {
#     'doc_freq': 1,
#     'docs': {758: [4]}
# }
# cannon: {
#     'doc_freq': 1,
#     'docs': {758: [14]}
# }
# dancing: {
#     'doc_freq': 1,
#     'docs': {758: [24]}
# }
# churchs: {
#     'doc_freq': 1,
#     'docs': {758: [28]}
# }
# hitter: {
#     'doc_freq': 1,
#     'docs': {758: [39]}
# }
# emad2: {
#     'doc_freq': 1,
#     'docs': {758: [42]}
# }
# onespot: {
#     'doc_freq': 2,
#     'docs': {760: [20, 73]}
# }
# 910: {
#     'doc_freq': 1,
#     'docs': {760: [23]}
# }
# holeyboard: {
#     'doc_freq': 1,
#     'docs': {760: [38]}
# }
# powering: {
#     'doc_freq': 1,
#     'docs': {760: [49]}
# }
# alter: {
#     'doc_freq': 1,
#     'docs': {760: [56]}
# }
# ego: {
#     'doc_freq': 1,
#     'docs': {760: [57]}
# }
# bug: {
#     'doc_freq': 1,
#     'docs': {760: [65]}
# }
# quieter: {
#     'doc_freq': 1,
#     'docs': {760: [77]}
# }
# leds: {
#     'doc_freq': 4,
#     'docs': {760: [85], 765: [11], 849: [78], 926: [31]}
# }
# hidden: {
#     'doc_freq': 2,
#     'docs': {760: [88], 831: [37]}
# }
# cinch: {
#     'doc_freq': 1,
#     'docs': {762: [14]}
# }
# ev15: {
#     'doc_freq': 1,
#     'docs': {764: [8]}
# }
# safety: {
#     'doc_freq': 1,
#     'docs': {764: [19]}
# }
# concern: {
#     'doc_freq': 3,
#     'docs': {764: [20], 767: [36], 873: [8]}
# }
# dropping: {
#     'doc_freq': 2,
#     'docs': {764: [25, 39]}
# }
# virtually: {
#     'doc_freq': 1,
#     'docs': {764: [31]}
# }
# desirable: {
#     'doc_freq': 1,
#     'docs': {764: [46]}
# }
# weddings: {
#     'doc_freq': 1,
#     'docs': {764: [47]}
# }
# drives: {
#     'doc_freq': 1,
#     'docs': {764: [49]}
# }
# springy: {
#     'doc_freq': 1,
#     'docs': {764: [53]}
# }
# spectrum: {
#     'doc_freq': 1,
#     'docs': {765: [22]}
# }
# uplighting: {
#     'doc_freq': 1,
#     'docs': {765: [33]}
# }
# beam: {
#     'doc_freq': 2,
#     'docs': {765: [54], 778: [4]}
# }
# blinding: {
#     'doc_freq': 1,
#     'docs': {765: [56]}
# }
# backing: {
#     'doc_freq': 3,
#     'docs': {766: [15], 861: [27, 47]}
# }
# backrest: {
#     'doc_freq': 2,
#     'docs': {766: [16, 20]}
# }
# clank: {
#     'doc_freq': 1,
#     'docs': {766: [21]}
# }
# trip: {
#     'doc_freq': 1,
#     'docs': {766: [22]}
# }
# cork: {
#     'doc_freq': 3,
#     'docs': {766: [26], 910: [21, 31]}
# }
# gambled: {
#     'doc_freq': 1,
#     'docs': {766: [36]}
# }
# claves: {
#     'doc_freq': 3,
#     'docs': {767: [2, 16, 28]}
# }
# piercing: {
#     'doc_freq': 1,
#     'docs': {767: [10]}
# }
# king: {
#     'doc_freq': 3,
#     'docs': {767: [15], 990: [17], 995: [29]}
# }
# knot: {
#     'doc_freq': 2,
#     'docs': {767: [25, 38]}
# }
# jupiter: {
#     'doc_freq': 1,
#     'docs': {767: [35]}
# }
# retro: {
#     'doc_freq': 1,
#     'docs': {768: [7]}
# }
# makeover: {
#     'doc_freq': 1,
#     'docs': {768: [8]}
# }
# cd: {
#     'doc_freq': 1,
#     'docs': {769: [8]}
# }
# 100mkii: {
#     'doc_freq': 1,
#     'docs': {769: [13]}
# }
# cells: {
#     'doc_freq': 2,
#     'docs': {769: [24, 36]}
# }
# dificult: {
#     'doc_freq': 1,
#     'docs': {769: [33]}
# }
# gloss: {
#     'doc_freq': 5,
#     'docs': {770: [11], 849: [62], 935: [14, 68, 86]}
# }
# plywood: {
#     'doc_freq': 2,
#     'docs': {770: [13], 846: [37]}
# }
# wore: {
#     'doc_freq': 2,
#     'docs': {770: [27], 875: [29]}
# }
# filing: {
#     'doc_freq': 1,
#     'docs': {770: [47]}
# }
# scales: {
#     'doc_freq': 1,
#     'docs': {770: [52]}
# }
# toddler: {
#     'doc_freq': 1,
#     'docs': {770: [58]}
# }
# child: {
#     'doc_freq': 1,
#     'docs': {770: [60]}
# }
# lessons: {
#     'doc_freq': 1,
#     'docs': {770: [68]}
# }
# false: {
#     'doc_freq': 1,
#     'docs': {770: [69]}
# }
# spruce: {
#     'doc_freq': 2,
#     'docs': {770: [70, 98]}
# }
# adult: {
#     'doc_freq': 1,
#     'docs': {770: [81]}
# }
# supervision: {
#     'doc_freq': 1,
#     'docs': {770: [82]}
# }
# catalpa: {
#     'doc_freq': 1,
#     'docs': {770: [100]}
# }
# mutch: {
#     'doc_freq': 1,
#     'docs': {771: [16]}
# }
# flute: {
#     'doc_freq': 2,
#     'docs': {772: [1, 23]}
# }
# guessing: {
#     'doc_freq': 1,
#     'docs': {772: [25]}
# }
# student: {
#     'doc_freq': 2,
#     'docs': {773: [5, 23]}
# }
# p90: {
#     'doc_freq': 1,
#     'docs': {774: [11]}
# }
# filed: {
#     'doc_freq': 1,
#     'docs': {774: [12]}
# }
# dab: {
#     'doc_freq': 1,
#     'docs': {774: [16]}
# }
# definite: {
#     'doc_freq': 1,
#     'docs': {774: [20]}
# }
# cs3: {
#     'doc_freq': 1,
#     'docs': {775: [3]}
# }
# silly: {
#     'doc_freq': 1,
#     'docs': {775: [16]}
# }
# acrylic: {
#     'doc_freq': 1,
#     'docs': {775: [21]}
# }
# cooler: {
#     'doc_freq': 2,
#     'docs': {775: [25], 849: [82]}
# }
# morpher: {
#     'doc_freq': 1,
#     'docs': {775: [27]}
# }
# mooer: {
#     'doc_freq': 2,
#     'docs': {775: [33, 39]}
# }
# contender: {
#     'doc_freq': 1,
#     'docs': {775: [34]}
# }
# tender: {
#     'doc_freq': 1,
#     'docs': {775: [40]}
# }
# octaver: {
#     'doc_freq': 1,
#     'docs': {775: [41]}
# }
# wowwwy: {
#     'doc_freq': 1,
#     'docs': {775: [43]}
# }
# defecting: {
#     'doc_freq': 1,
#     'docs': {776: [16]}
# }
# grabber: {
#     'doc_freq': 1,
#     'docs': {776: [25]}
# }
# 114e: {
#     'doc_freq': 1,
#     'docs': {776: [28]}
# }
# peel: {
#     'doc_freq': 1,
#     'docs': {777: [45]}
# }
# goop: {
#     'doc_freq': 1,
#     'docs': {777: [47]}
# }
# hassle: {
#     'doc_freq': 1,
#     'docs': {777: [50]}
# }
# 0000: {
#     'doc_freq': 1,
#     'docs': {777: [52]}
# }
# grade: {
#     'doc_freq': 2,
#     'docs': {777: [53], 884: [10]}
# }
# wool: {
#     'doc_freq': 1,
#     'docs': {777: [55]}
# }
# brightness: {
#     'doc_freq': 3,
#     'docs': {778: [2, 34], 980: [23]}
# }
# songwriter: {
#     'doc_freq': 1,
#     'docs': {779: [5]}
# }
# shine: {
#     'doc_freq': 1,
#     'docs': {779: [6]}
# }
# chris: {
#     'doc_freq': 1,
#     'docs': {779: [11]}
# }
# parlor: {
#     'doc_freq': 1,
#     'docs': {780: [7]}
# }
# dread: {
#     'doc_freq': 1,
#     'docs': {780: [15]}
# }
# 36: {
#     'doc_freq': 2,
#     'docs': {780: [22], 849: [70]}
# }
# 2013: {
#     'doc_freq': 1,
#     'docs': {781: [5]}
# }
# burstbucker: {
#     'doc_freq': 3,
#     'docs': {781: [6, 9, 38]}
# }
# paf: {
#     'doc_freq': 1,
#     'docs': {781: [15]}
# }
# specification: {
#     'doc_freq': 1,
#     'docs': {781: [23]}
# }
# pafs: {
#     'doc_freq': 1,
#     'docs': {781: [24]}
# }
# es335: {
#     'doc_freq': 1,
#     'docs': {781: [30]}
# }
# jazzybluesy: {
#     'doc_freq': 1,
#     'docs': {781: [57]}
# }
# neglecting: {
#     'doc_freq': 1,
#     'docs': {781: [67]}
# }
# chores: {
#     'doc_freq': 1,
#     'docs': {781: [68]}
# }
# enjoying: {
#     'doc_freq': 1,
#     'docs': {781: [72]}
# }
# til: {
#     'doc_freq': 2,
#     'docs': {782: [2], 859: [11]}
# }
# techs: {
#     'doc_freq': 1,
#     'docs': {782: [12]}
# }
# defeat: {
#     'doc_freq': 1,
#     'docs': {783: [4]}
# }
# pinkpurple: {
#     'doc_freq': 1,
#     'docs': {784: [16]}
# }
# starts: {
#     'doc_freq': 3,
#     'docs': {784: [24], 794: [24], 911: [22]}
# }
# booth: {
#     'doc_freq': 1,
#     'docs': {784: [35]}
# }
# bundle: {
#     'doc_freq': 1,
#     'docs': {786: [2]}
# }
# offbrand: {
#     'doc_freq': 1,
#     'docs': {787: [2]}
# }
# excellently: {
#     'doc_freq': 1,
#     'docs': {787: [5]}
# }
# resonates: {
#     'doc_freq': 1,
#     'docs': {787: [6]}
# }
# amplifying: {
#     'doc_freq': 1,
#     'docs': {787: [23]}
# }
# properties: {
#     'doc_freq': 1,
#     'docs': {787: [29]}
# }
# drape: {
#     'doc_freq': 1,
#     'docs': {787: [32]}
# }
# wellassembled: {
#     'doc_freq': 1,
#     'docs': {787: [37]}
# }
# welcome: {
#     'doc_freq': 1,
#     'docs': {787: [47]}
# }
# advice: {
#     'doc_freq': 2,
#     'docs': {788: [15], 910: [52]}
# }
# newbie: {
#     'doc_freq': 1,
#     'docs': {788: [25]}
# }
# exercises: {
#     'doc_freq': 1,
#     'docs': {788: [32]}
# }
# skilled: {
#     'doc_freq': 1,
#     'docs': {788: [41]}
# }
# altotenor: {
#     'doc_freq': 1,
#     'docs': {789: [5]}
# }
# gigshome: {
#     'doc_freq': 1,
#     'docs': {789: [25]}
# }
# doubled: {
#     'doc_freq': 1,
#     'docs': {789: [29]}
# }
# snaps: {
#     'doc_freq': 1,
#     'docs': {789: [36]}
# }
# wobbling: {
#     'doc_freq': 1,
#     'docs': {789: [50]}
# }
# 62iii: {
#     'doc_freq': 1,
#     'docs': {789: [57]}
# }
# allora: {
#     'doc_freq': 1,
#     'docs': {789: [59]}
# }
# woodwind: {
#     'doc_freq': 1,
#     'docs': {789: [61]}
# }
# brasswind: {
#     'doc_freq': 1,
#     'docs': {789: [62]}
# }
# unsanded: {
#     'doc_freq': 1,
#     'docs': {790: [12]}
# }
# beveling: {
#     'doc_freq': 1,
#     'docs': {790: [32]}
# }
# 18and: {
#     'doc_freq': 1,
#     'docs': {790: [41]}
# }
# workmanship: {
#     'doc_freq': 1,
#     'docs': {790: [45]}
# }
# unfinished: {
#     'doc_freq': 1,
#     'docs': {790: [46]}
# }
# unbeveled: {
#     'doc_freq': 1,
#     'docs': {790: [47]}
# }
# michael: {
#     'doc_freq': 1,
#     'docs': {791: [4]}
# }
# sucker: {
#     'doc_freq': 1,
#     'docs': {791: [10]}
# }
# simplest: {
#     'doc_freq': 1,
#     'docs': {792: [5]}
# }
# wass: {
#     'doc_freq': 1,
#     'docs': {793: [6]}
# }
# stubbed: {
#     'doc_freq': 1,
#     'docs': {793: [25]}
# }
# toe: {
#     'doc_freq': 1,
#     'docs': {793: [26]}
# }
# wished: {
#     'doc_freq': 1,
#     'docs': {793: [29]}
# }
# riveted: {
#     'doc_freq': 1,
#     'docs': {793: [36]}
# }
# standing: {
#     'doc_freq': 1,
#     'docs': {793: [42]}
# }
# dangers: {
#     'doc_freq': 1,
#     'docs': {793: [63]}
# }
# scissoring: {
#     'doc_freq': 1,
#     'docs': {793: [64]}
# }
# hurtin: {
#     'doc_freq': 1,
#     'docs': {793: [69]}
# }
# cheapbudget: {
#     'doc_freq': 1,
#     'docs': {794: [4]}
# }
# layering: {
#     'doc_freq': 1,
#     'docs': {794: [21]}
# }
# beatup: {
#     'doc_freq': 2,
#     'docs': {796: [3, 74]}
# }
# juan: {
#     'doc_freq': 1,
#     'docs': {796: [4]}
# }
# estruch: {
#     'doc_freq': 1,
#     'docs': {796: [5]}
# }
# flea: {
#     'doc_freq': 1,
#     'docs': {796: [9]}
# }
# rusty: {
#     'doc_freq': 1,
#     'docs': {796: [22]}
# }
# anouncement: {
#     'doc_freq': 1,
#     'docs': {797: [1]}
# }
# emerson: {
#     'doc_freq': 1,
#     'docs': {797: [6]}
# }
# tonecapacitor: {
#     'doc_freq': 1,
#     'docs': {797: [13]}
# }
# sister: {
#     'doc_freq': 1,
#     'docs': {798: [2]}
# }
# law: {
#     'doc_freq': 1,
#     'docs': {798: [4]}
# }
# babysitting: {
#     'doc_freq': 1,
#     'docs': {798: [5]}
# }
# sick: {
#     'doc_freq': 1,
#     'docs': {798: [32]}
# }
# awful: {
#     'doc_freq': 1,
#     'docs': {801: [22]}
# }
# beige: {
#     'doc_freq': 1,
#     'docs': {801: [43]}
# }
# explained: {
#     'doc_freq': 1,
#     'docs': {801: [55]}
# }
# modificationsif: {
#     'doc_freq': 1,
#     'docs': {801: [68]}
# }
# 1gap: {
#     'doc_freq': 1,
#     'docs': {802: [5]}
# }
# slippery: {
#     'doc_freq': 1,
#     'docs': {803: [25]}
# }
# yellowish: {
#     'doc_freq': 1,
#     'docs': {803: [38]}
# }
# platinum: {
#     'doc_freq': 1,
#     'docs': {804: [5]}
# }
# 150hz: {
#     'doc_freq': 1,
#     'docs': {804: [19]}
# }
# 30hz: {
#     'doc_freq': 1,
#     'docs': {804: [24]}
# }
# 80hz: {
#     'doc_freq': 1,
#     'docs': {804: [25]}
# }
# 160hz: {
#     'doc_freq': 1,
#     'docs': {804: [26]}
# }
# 200hz31khz: {
#     'doc_freq': 1,
#     'docs': {804: [28]}
# }
# q13: {
#     'doc_freq': 1,
#     'docs': {804: [29]}
# }
# 6khz: {
#     'doc_freq': 1,
#     'docs': {804: [31]}
# }
# bose: {
#     'doc_freq': 1,
#     'docs': {804: [36]}
# }
# s1: {
#     'doc_freq': 1,
#     'docs': {804: [37]}
# }
# f7: {
#     'doc_freq': 1,
#     'docs': {804: [45]}
# }
# paco: {
#     'doc_freq': 1,
#     'docs': {804: [46]}
# }
# ellipse: {
#     'doc_freq': 1,
#     'docs': {804: [49]}
# }
# fishmanelectronics: {
#     'doc_freq': 1,
#     'docs': {804: [54]}
# }
# amongst: {
#     'doc_freq': 1,
#     'docs': {805: [5]}
# }
# antique: {
#     'doc_freq': 1,
#     'docs': {805: [10]}
# }
# german: {
#     'doc_freq': 1,
#     'docs': {805: [11]}
# }
# lute: {
#     'doc_freq': 2,
#     'docs': {805: [12, 30]}
# }
# wandervogellaute: {
#     'doc_freq': 1,
#     'docs': {805: [14]}
# }
# complements: {
#     'doc_freq': 1,
#     'docs': {805: [18]}
# }
# rosette: {
#     'doc_freq': 1,
#     'docs': {805: [20]}
# }
# vaguely: {
#     'doc_freq': 1,
#     'docs': {805: [23]}
# }
# ecclesiastical: {
#     'doc_freq': 1,
#     'docs': {805: [24]}
# }
# motif: {
#     'doc_freq': 1,
#     'docs': {805: [25]}
# }
# hippie: {
#     'doc_freq': 1,
#     'docs': {805: [29]}
# }
# wammy: {
#     'doc_freq': 1,
#     'docs': {806: [14]}
# }
# silicone: {
#     'doc_freq': 1,
#     'docs': {808: [17]}
# }
# jacket: {
#     'doc_freq': 1,
#     'docs': {808: [18]}
# }
# shortened: {
#     'doc_freq': 1,
#     'docs': {808: [20]}
# }
# lyxpro: {
#     'doc_freq': 1,
#     'docs': {808: [22]}
# }
# bayand: {
#     'doc_freq': 1,
#     'docs': {808: [31]}
# }
# neutrix: {
#     'doc_freq': 1,
#     'docs': {808: [34]}
# }
# trs: {
#     'doc_freq': 2,
#     'docs': {808: [35, 43]}
# }
# neutric: {
#     'doc_freq': 1,
#     'docs': {808: [37]}
# }
# seismic: {
#     'doc_freq': 1,
#     'docs': {808: [47]}
# }
# mmx: {
#     'doc_freq': 1,
#     'docs': {809: [10]}
# }
# retina: {
#     'doc_freq': 1,
#     'docs': {810: [6]}
# }
# sequencing: {
#     'doc_freq': 1,
#     'docs': {810: [8]}
# }
# mc303: {
#     'doc_freq': 1,
#     'docs': {810: [11]}
# }
# opens: {
#     'doc_freq': 1,
#     'docs': {810: [15]}
# }
# compatibilities: {
#     'doc_freq': 1,
#     'docs': {810: [22]}
# }
# controllers: {
#     'doc_freq': 2,
#     'docs': {810: [29], 981: [27]}
# }
# atr2100: {
#     'doc_freq': 1,
#     'docs': {811: [5]}
# }
# tests: {
#     'doc_freq': 1,
#     'docs': {811: [13]}
# }
# plosives: {
#     'doc_freq': 2,
#     'docs': {811: [15], 871: [12]}
# }
# brite: {
#     'doc_freq': 1,
#     'docs': {812: [7]}
# }
# chromatic: {
#     'doc_freq': 1,
#     'docs': {812: [11]}
# }
# tunings: {
#     'doc_freq': 1,
#     'docs': {812: [17]}
# }
# 432: {
#     'doc_freq': 1,
#     'docs': {812: [19]}
# }
# inactivity: {
#     'doc_freq': 1,
#     'docs': {812: [33]}
# }
# drain: {
#     'doc_freq': 1,
#     'docs': {812: [34]}
# }
# invited: {
#     'doc_freq': 1,
#     'docs': {813: [1]}
# }
# quasidixieland: {
#     'doc_freq': 2,
#     'docs': {813: [3, 5]}
# }
# di: {
#     'doc_freq': 1,
#     'docs': {813: [29]}
# }
# xt65r: {
#     'doc_freq': 1,
#     'docs': {813: [42]}
# }
# photographs: {
#     'doc_freq': 1,
#     'docs': {813: [79]}
# }
# race: {
#     'doc_freq': 1,
#     'docs': {813: [83]}
# }
# creek: {
#     'doc_freq': 1,
#     'docs': {813: [84]}
# }
# readjust: {
#     'doc_freq': 1,
#     'docs': {814: [5]}
# }
# suppose: {
#     'doc_freq': 1,
#     'docs': {815: [36]}
# }
# misleading: {
#     'doc_freq': 1,
#     'docs': {815: [44]}
# }
# telecasters: {
#     'doc_freq': 1,
#     'docs': {815: [49]}
# }
# filling: {
#     'doc_freq': 2,
#     'docs': {817: [2], 969: [14]}
# }
# gladly: {
#     'doc_freq': 1,
#     'docs': {817: [13]}
# }
# thumbs: {
#     'doc_freq': 1,
#     'docs': {817: [16]}
# }
# raises: {
#     'doc_freq': 1,
#     'docs': {817: [24]}
# }
# smoke: {
#     'doc_freq': 2,
#     'docs': {817: [29], 839: [22]}
# }
# dances: {
#     'doc_freq': 1,
#     'docs': {817: [32]}
# }
# theyve: {
#     'doc_freq': 1,
#     'docs': {818: [9]}
# }
# usage: {
#     'doc_freq': 1,
#     'docs': {819: [4]}
# }
# axerig: {
#     'doc_freq': 2,
#     'docs': {819: [5, 65]}
# }
# glasses: {
#     'doc_freq': 1,
#     'docs': {819: [17]}
# }
# testify: {
#     'doc_freq': 1,
#     'docs': {819: [60]}
# }
# rounded: {
#     'doc_freq': 1,
#     'docs': {821: [7]}
# }
# valley: {
#     'doc_freq': 1,
#     'docs': {821: [8]}
# }
# edged: {
#     'doc_freq': 1,
#     'docs': {821: [11]}
# }
# curvature: {
#     'doc_freq': 1,
#     'docs': {821: [24]}
# }
# finishing: {
#     'doc_freq': 1,
#     'docs': {822: [4]}
# }
# preferences: {
#     'doc_freq': 1,
#     'docs': {823: [6]}
# }
# slinky: {
#     'doc_freq': 4,
#     'docs': {823: [22, 46], 880: [50, 68]}
# }
# 05252017still: {
#     'doc_freq': 1,
#     'docs': {823: [30]}
# }
# yoke: {
#     'doc_freq': 1,
#     'docs': {824: [35]}
# }
# 7string: {
#     'doc_freq': 1,
#     'docs': {824: [38]}
# }
# 5string: {
#     'doc_freq': 2,
#     'docs': {824: [44], 880: [49]}
# }
# 5stars: {
#     'doc_freq': 1,
#     'docs': {825: [3]}
# }
# filledin: {
#     'doc_freq': 1,
#     'docs': {825: [4]}
# }
# cleanly: {
#     'doc_freq': 1,
#     'docs': {825: [15]}
# }
# usba: {
#     'doc_freq': 1,
#     'docs': {825: [24]}
# }
# usbb: {
#     'doc_freq': 1,
#     'docs': {825: [25]}
# }
# btoa: {
#     'doc_freq': 1,
#     'docs': {825: [39]}
# }
# charging: {
#     'doc_freq': 1,
#     'docs': {825: [43]}
# }
# charger: {
#     'doc_freq': 1,
#     'docs': {825: [52]}
# }
# responses: {
#     'doc_freq': 1,
#     'docs': {825: [55]}
# }
# qa: {
#     'doc_freq': 1,
#     'docs': {825: [56]}
# }
# suppliers: {
#     'doc_freq': 1,
#     'docs': {825: [61]}
# }
# chipping: {
#     'doc_freq': 1,
#     'docs': {826: [7]}
# }
# 5hole: {
#     'doc_freq': 1,
#     'docs': {827: [2]}
# }
# eggshell: {
#     'doc_freq': 2,
#     'docs': {827: [4, 40]}
# }
# baja: {
#     'doc_freq': 1,
#     'docs': {827: [6]}
# }
# bakelite: {
#     'doc_freq': 1,
#     'docs': {827: [21]}
# }
# anodized: {
#     'doc_freq': 1,
#     'docs': {827: [25]}
# }
# warmth: {
#     'doc_freq': 1,
#     'docs': {827: [44]}
# }
# shielding: {
#     'doc_freq': 1,
#     'docs': {827: [46]}
# }
# slap: {
#     'doc_freq': 2,
#     'docs': {827: [49], 895: [2]}
# }
# squiers: {
#     'doc_freq': 1,
#     'docs': {827: [54]}
# }
# neg: {
#     'doc_freq': 1,
#     'docs': {828: [14]}
# }
# pen: {
#     'doc_freq': 1,
#     'docs': {828: [40]}
# }
# flap: {
#     'doc_freq': 1,
#     'docs': {828: [44]}
# }
# hinge: {
#     'doc_freq': 1,
#     'docs': {828: [45]}
# }
# expose: {
#     'doc_freq': 1,
#     'docs': {828: [48]}
# }
# removes: {
#     'doc_freq': 2,
#     'docs': {828: [52], 918: [36]}
# }
# disassemble: {
#     'doc_freq': 1,
#     'docs': {828: [55]}
# }
# understanding: {
#     'doc_freq': 1,
#     'docs': {828: [61]}
# }
# nan: {
#     'doc_freq': 1,
#     'docs': {829: [1]}
# }
# slanted: {
#     'doc_freq': 1,
#     'docs': {830: [34]}
# }
# operator: {
#     'doc_freq': 1,
#     'docs': {830: [36]}
# }
# configured: {
#     'doc_freq': 1,
#     'docs': {830: [41]}
# }
# fantabulous: {
#     'doc_freq': 1,
#     'docs': {831: [2]}
# }
# upright: {
#     'doc_freq': 1,
#     'docs': {831: [9]}
# }
# tnt: {
#     'doc_freq': 1,
#     'docs': {831: [17]}
# }
# belly: {
#     'doc_freq': 1,
#     'docs': {831: [23]}
# }
# beneath: {
#     'doc_freq': 1,
#     'docs': {831: [38]}
# }
# humongous: {
#     'doc_freq': 1,
#     'docs': {833: [9]}
# }
# wires: {
#     'doc_freq': 1,
#     'docs': {833: [32]}
# }
# hardly: {
#     'doc_freq': 1,
#     'docs': {834: [9]}
# }
# noting: {
#     'doc_freq': 1,
#     'docs': {834: [11]}
# }
# intuitive: {
#     'doc_freq': 1,
#     'docs': {834: [14]}
# }
# designated: {
#     'doc_freq': 1,
#     'docs': {834: [30]}
# }
# grows: {
#     'doc_freq': 1,
#     'docs': {835: [26]}
# }
# mismatching: {
#     'doc_freq': 1,
#     'docs': {835: [27]}
# }
# brook: {
#     'doc_freq': 2,
#     'docs': {835: [35, 60]}
# }
# mays: {
#     'doc_freq': 2,
#     'docs': {835: [36, 61]}
# }
# closely: {
#     'doc_freq': 1,
#     'docs': {835: [40]}
# }
# extrememly: {
#     'doc_freq': 1,
#     'docs': {835: [46]}
# }
# emails: {
#     'doc_freq': 1,
#     'docs': {835: [51]}
# }
# concerning: {
#     'doc_freq': 1,
#     'docs': {835: [52]}
# }
# request: {
#     'doc_freq': 1,
#     'docs': {835: [53]}
# }
# promises: {
#     'doc_freq': 1,
#     'docs': {835: [58]}
# }
# ponys: {
#     'doc_freq': 1,
#     'docs': {836: [22]}
# }
# gamble: {
#     'doc_freq': 1,
#     'docs': {836: [27]}
# }
# inear: {
#     'doc_freq': 1,
#     'docs': {837: [7]}
# }
# compartments: {
#     'doc_freq': 2,
#     'docs': {838: [20], 864: [13]}
# }
# pedels: {
#     'doc_freq': 1,
#     'docs': {838: [23]}
# }
# kumbaya: {
#     'doc_freq': 1,
#     'docs': {839: [12]}
# }
# gang: {
#     'doc_freq': 1,
#     'docs': {839: [13]}
# }
# camp: {
#     'doc_freq': 1,
#     'docs': {839: [15]}
# }
# salt: {
#     'doc_freq': 1,
#     'docs': {839: [24]}
# }
# spray: {
#     'doc_freq': 2,
#     'docs': {839: [25], 884: [45]}
# }
# act: {
#     'doc_freq': 1,
#     'docs': {839: [31]}
# }
# impression: {
#     'doc_freq': 1,
#     'docs': {839: [45]}
# }
# forearm: {
#     'doc_freq': 1,
#     'docs': {839: [56]}
# }
# town: {
#     'doc_freq': 3,
#     'docs': {839: [59], 886: [14, 57]}
# }
# maintain: {
#     'doc_freq': 1,
#     'docs': {839: [74]}
# }
# furniture: {
#     'doc_freq': 1,
#     'docs': {839: [75]}
# }
# ass: {
#     'doc_freq': 1,
#     'docs': {840: [4]}
# }
# crunchy: {
#     'doc_freq': 2,
#     'docs': {840: [17], 880: [31]}
# }
# looped: {
#     'doc_freq': 1,
#     'docs': {841: [17]}
# }
# kona: {
#     'doc_freq': 1,
#     'docs': {842: [4]}
# }
# k1etrd: {
#     'doc_freq': 1,
#     'docs': {842: [5]}
# }
# vast: {
#     'doc_freq': 2,
#     'docs': {842: [6], 870: [66]}
# }
# reeck: {
#     'doc_freq': 1,
#     'docs': {843: [8]}
# }
# usingthis: {
#     'doc_freq': 1,
#     'docs': {843: [12]}
# }
# hawaiian: {
#     'doc_freq': 1,
#     'docs': {844: [6]}
# }
# performing: {
#     'doc_freq': 2,
#     'docs': {844: [7], 870: [77]}
# }
# arts: {
#     'doc_freq': 1,
#     'docs': {844: [8]}
# }
# headsets: {
#     'doc_freq': 2,
#     'docs': {844: [10, 31]}
# }
# singer: {
#     'doc_freq': 1,
#     'docs': {844: [15]}
# }
# moves: {
#     'doc_freq': 1,
#     'docs': {844: [16]}
# }
# lays: {
#     'doc_freq': 1,
#     'docs': {845: [22]}
# }
# surge: {
#     'doc_freq': 1,
#     'docs': {846: [26]}
# }
# compactly: {
#     'doc_freq': 1,
#     'docs': {846: [35]}
# }
# cabinet: {
#     'doc_freq': 2,
#     'docs': {847: [10, 22]}
# }
# jensen: {
#     'doc_freq': 1,
#     'docs': {847: [11]}
# }
# c8r4: {
#     'doc_freq': 1,
#     'docs': {847: [13]}
# }
# 8inch: {
#     'doc_freq': 1,
#     'docs': {847: [14]}
# }
# delayreverb: {
#     'doc_freq': 1,
#     'docs': {847: [36]}
# }
# setups: {
#     'doc_freq': 1,
#     'docs': {847: [45]}
# }
# chipamp: {
#     'doc_freq': 1,
#     'docs': {847: [60]}
# }
# hotone: {
#     'doc_freq': 1,
#     'docs': {847: [71]}
# }
# legacy: {
#     'doc_freq': 1,
#     'docs': {847: [74]}
# }
# british: {
#     'doc_freq': 1,
#     'docs': {847: [75]}
# }
# invasion: {
#     'doc_freq': 1,
#     'docs': {847: [76]}
# }
# pearls: {
#     'doc_freq': 1,
#     'docs': {848: [7]}
# }
# bouncing: {
#     'doc_freq': 1,
#     'docs': {848: [20]}
# }
# lug: {
#     'doc_freq': 1,
#     'docs': {848: [21]}
# }
# suspension: {
#     'doc_freq': 1,
#     'docs': {848: [34]}
# }
# birch: {
#     'doc_freq': 1,
#     'docs': {848: [39]}
# }
# vision: {
#     'doc_freq': 1,
#     'docs': {848: [40]}
# }
# iss: {
#     'doc_freq': 1,
#     'docs': {848: [46]}
# }
# optimounts: {
#     'doc_freq': 1,
#     'docs': {848: [58]}
# }
# masterworks: {
#     'doc_freq': 1,
#     'docs': {848: [67]}
# }
# accent: {
#     'doc_freq': 1,
#     'docs': {848: [74]}
# }
# shells: {
#     'doc_freq': 2,
#     'docs': {848: [76, 87]}
# }
# intrusive: {
#     'doc_freq': 1,
#     'docs': {848: [78]}
# }
# hurts: {
#     'doc_freq': 1,
#     'docs': {848: [89]}
# }
# underbed: {
#     'doc_freq': 2,
#     'docs': {849: [5, 38]}
# }
# kings: {
#     'doc_freq': 2,
#     'docs': {849: [10], 903: [23]}
# }
# food: {
#     'doc_freq': 1,
#     'docs': {849: [15]}
# }
# headboard: {
#     'doc_freq': 1,
#     'docs': {849: [16]}
# }
# permitter: {
#     'doc_freq': 1,
#     'docs': {849: [18]}
# }
# dimming: {
#     'doc_freq': 2,
#     'docs': {849: [24, 83]}
# }
# nightlight: {
#     'doc_freq': 2,
#     'docs': {849: [29, 39]}
# }
# dimmest: {
#     'doc_freq': 1,
#     'docs': {849: [36]}
# }
# lit: {
#     'doc_freq': 1,
#     'docs': {849: [43]}
# }
# deduction: {
#     'doc_freq': 1,
#     'docs': {849: [46]}
# }
# stickier: {
#     'doc_freq': 1,
#     'docs': {849: [50]}
# }
# scotch: {
#     'doc_freq': 1,
#     'docs': {849: [53]}
# }
# adhere: {
#     'doc_freq': 1,
#     'docs': {849: [57]}
# }
# nontextured: {
#     'doc_freq': 1,
#     'docs': {849: [61]}
# }
# dimmer: {
#     'doc_freq': 1,
#     'docs': {849: [67]}
# }
# ideally: {
#     'doc_freq': 1,
#     'docs': {849: [69]}
# }
# temperature: {
#     'doc_freq': 1,
#     'docs': {849: [80]}
# }
# becomes: {
#     'doc_freq': 1,
#     'docs': {849: [81]}
# }
# glam: {
#     'doc_freq': 1,
#     'docs': {850: [24]}
# }
# buzzy: {
#     'doc_freq': 1,
#     'docs': {850: [43]}
# }
# mere: {
#     'doc_freq': 1,
#     'docs': {850: [53]}
# }
# dice: {
#     'doc_freq': 1,
#     'docs': {850: [57]}
# }
# at2100: {
#     'doc_freq': 1,
#     'docs': {851: [5]}
# }
# 23: {
#     'doc_freq': 1,
#     'docs': {851: [24]}
# }
# bassy: {
#     'doc_freq': 1,
#     'docs': {851: [30]}
# }
# trait: {
#     'doc_freq': 1,
#     'docs': {852: [23]}
# }
# dent: {
#     'doc_freq': 1,
#     'docs': {853: [28]}
# }
# chin: {
#     'doc_freq': 1,
#     'docs': {853: [42]}
# }
# buzzed: {
#     'doc_freq': 1,
#     'docs': {854: [13]}
# }
# lent: {
#     'doc_freq': 1,
#     'docs': {855: [1]}
# }
# c2: {
#     'doc_freq': 1,
#     'docs': {855: [8]}
# }
# hugs: {
#     'doc_freq': 1,
#     'docs': {855: [18]}
# }
# lipsticksized: {
#     'doc_freq': 1,
#     'docs': {855: [19]}
# }
# c2s: {
#     'doc_freq': 1,
#     'docs': {855: [20]}
# }
# caresses: {
#     'doc_freq': 1,
#     'docs': {855: [22]}
# }
# tapering: {
#     'doc_freq': 1,
#     'docs': {855: [23]}
# }
# ice: {
#     'doc_freq': 1,
#     'docs': {855: [24]}
# }
# cone: {
#     'doc_freq': 1,
#     'docs': {855: [26]}
# }
# r21: {
#     'doc_freq': 1,
#     'docs': {855: [32]}
# }
# elsewhere: {
#     'doc_freq': 3,
#     'docs': {858: [2], 905: [20], 932: [13]}
# }
# emphasis: {
#     'doc_freq': 1,
#     'docs': {858: [42]}
# }
# habit: {
#     'doc_freq': 1,
#     'docs': {858: [45]}
# }
# unlearn: {
#     'doc_freq': 1,
#     'docs': {858: [47]}
# }
# before: {
#     'doc_freq': 1,
#     'docs': {859: [3]}
# }
# accubass: {
#     'doc_freq': 2,
#     'docs': {859: [34], 886: [41]}
# }
# stringthrough: {
#     'doc_freq': 1,
#     'docs': {859: [35]}
# }
# explain: {
#     'doc_freq': 2,
#     'docs': {859: [37], 930: [23]}
# }
# silks: {
#     'doc_freq': 1,
#     'docs': {859: [38]}
# }
# latest: {
#     'doc_freq': 1,
#     'docs': {861: [4]}
# }
# accepted: {
#     'doc_freq': 1,
#     'docs': {861: [9]}
# }
# cavities: {
#     'doc_freq': 2,
#     'docs': {861: [18], 937: [65]}
# }
# pill: {
#     'doc_freq': 1,
#     'docs': {861: [37]}
# }
# formed: {
#     'doc_freq': 1,
#     'docs': {861: [40]}
# }
# recoil: {
#     'doc_freq': 1,
#     'docs': {861: [48]}
# }
# rendition: {
#     'doc_freq': 1,
#     'docs': {862: [8]}
# }
# macawber: {
#     'doc_freq': 1,
#     'docs': {862: [9]}
# }
# keith: {
#     'doc_freq': 1,
#     'docs': {862: [10]}
# }
# richards: {
#     'doc_freq': 1,
#     'docs': {862: [11]}
# }
# guards: {
#     'doc_freq': 1,
#     'docs': {862: [34]}
# }
# matte: {
#     'doc_freq': 1,
#     'docs': {862: [41]}
# }
# inwas: {
#     'doc_freq': 1,
#     'docs': {863: [1]}
# }
# specting: {
#     'doc_freq': 1,
#     'docs': {863: [2]}
# }
# khanka: {
#     'doc_freq': 1,
#     'docs': {863: [20]}
# }
# preffered: {
#     'doc_freq': 1,
#     'docs': {863: [37]}
# }
# zip: {
#     'doc_freq': 2,
#     'docs': {864: [11], 879: [38]}
# }
# sheet: {
#     'doc_freq': 2,
#     'docs': {864: [16], 935: [38]}
# }
# unbearable: {
#     'doc_freq': 1,
#     'docs': {865: [12]}
# }
# suited: {
#     'doc_freq': 1,
#     'docs': {865: [38]}
# }
# bedroom: {
#     'doc_freq': 3,
#     'docs': {865: [39], 883: [5, 12]}
# }
# hd: {
#     'doc_freq': 1,
#     'docs': {866: [2]}
# }
# aids: {
#     'doc_freq': 1,
#     'docs': {866: [7]}
# }
# fascinated: {
#     'doc_freq': 1,
#     'docs': {866: [13]}
# }
# fidelity: {
#     'doc_freq': 1,
#     'docs': {866: [15]}
# }
# djmaximo: {
#     'doc_freq': 1,
#     'docs': {866: [22]}
# }
# loosely: {
#     'doc_freq': 1,
#     'docs': {867: [11]}
# }
# identify: {
#     'doc_freq': 1,
#     'docs': {867: [19]}
# }
# mechanically: {
#     'doc_freq': 1,
#     'docs': {867: [28]}
# }
# challenged: {
#     'doc_freq': 1,
#     'docs': {867: [29]}
# }
# exhibit: {
#     'doc_freq': 1,
#     'docs': {868: [12]}
# }
# hipshot: {
#     'doc_freq': 1,
#     'docs': {868: [31]}
# }
# cardiod: {
#     'doc_freq': 2,
#     'docs': {870: [13, 69]}
# }
# polar: {
#     'doc_freq': 1,
#     'docs': {870: [14]}
# }
# 300ohm: {
#     'doc_freq': 1,
#     'docs': {870: [31]}
# }
# weighs: {
#     'doc_freq': 1,
#     'docs': {870: [32]}
# }
# 9oz: {
#     'doc_freq': 1,
#     'docs': {870: [33]}
# }
# 3pin: {
#     'doc_freq': 1,
#     'docs': {870: [34]}
# }
# xlrm: {
#     'doc_freq': 1,
#     'docs': {870: [35]}
# }
# 9016000hz: {
#     'doc_freq': 1,
#     'docs': {870: [36]}
# }
# durability: {
#     'doc_freq': 1,
#     'docs': {870: [41]}
# }
# magnets: {
#     'doc_freq': 1,
#     'docs': {870: [47]}
# }
# majority: {
#     'doc_freq': 1,
#     'docs': {870: [67]}
# }
# industry: {
#     'doc_freq': 1,
#     'docs': {871: [8]}
# }
# affecting: {
#     'doc_freq': 1,
#     'docs': {871: [14]}
# }
# visuallyappealing: {
#     'doc_freq': 1,
#     'docs': {871: [20]}
# }
# beta: {
#     'doc_freq': 2,
#     'docs': {871: [24, 51]}
# }
# 87c: {
#     'doc_freq': 1,
#     'docs': {871: [25]}
# }
# ballshaped: {
#     'doc_freq': 2,
#     'docs': {871: [26, 29]}
# }
# tv: {
#     'doc_freq': 1,
#     'docs': {871: [38]}
# }
# a85ws: {
#     'doc_freq': 1,
#     'docs': {871: [40]}
# }
# wayne: {
#     'doc_freq': 1,
#     'docs': {871: [41]}
# }
# brady: {
#     'doc_freq': 1,
#     'docs': {871: [42]}
# }
# jonathan: {
#     'doc_freq': 1,
#     'docs': {871: [43]}
# }
# mangum: {
# ...
# }
# brute: {
#     'doc_freq': 1,
#     'docs': {911: [34]}
# }
# wp: {
#     'doc_freq': 3,
#     'docs': {912: [4, 52, 66]}
# }
# gray: {
#     'doc_freq': 1,
#     'docs': {912: [15]}
# }
# cast: {
#     'doc_freq': 1,
#     'docs': {912: [17]}
# }
# awp: {
#     'doc_freq': 3,
#     'docs': {912: [22, 55, 77]}
# }
# tbhey: {
#     'doc_freq': 1,
#     'docs': {912: [29]}
# }
# nose: {
#     'doc_freq': 1,
#     'docs': {912: [39]}
# }
# realism: {
#     'doc_freq': 1,
#     'docs': {912: [71]}
# }
# ideal: {
#     'doc_freq': 1,
#     'docs': {913: [1]}
# }
# heaps: {
#     'doc_freq': 1,
#     'docs': {913: [20]}
# }
# webcam: {
#     'doc_freq': 1,
#     'docs': {913: [24]}
# }
# weighty: {
#     'doc_freq': 1,
#     'docs': {913: [38]}
# }
# hell: {
#     'doc_freq': 2,
#     'docs': {913: [44], 961: [12]}
# }
# casio: {
#     'doc_freq': 1,
#     'docs': {914: [4]}
# }
# px160: {
#     'doc_freq': 1,
#     'docs': {914: [5]}
# }
# afraid: {
#     'doc_freq': 1,
#     'docs': {915: [1]}
# }
# 1994: {
#     'doc_freq': 1,
#     'docs': {915: [12]}
# }
# wiggling: {
#     'doc_freq': 1,
#     'docs': {915: [20]}
# }
# strategic: {
#     'doc_freq': 1,
#     'docs': {915: [21]}
# }
# creamoff: {
#     'doc_freq': 1,
#     'docs': {915: [33]}
# }
# delivery: {
#     'doc_freq': 1,
#     'docs': {915: [57]}
# }
# envelope: {
#     'doc_freq': 1,
#     'docs': {915: [59]}
# }
# dashboard: {
#     'doc_freq': 1,
#     'docs': {915: [62]}
# }
# flare: {
#     'doc_freq': 1,
#     'docs': {916: [6]}
# }
# bronco: {
#     'doc_freq': 1,
#     'docs': {916: [12]}
# }
# atnear: {
#     'doc_freq': 1,
#     'docs': {916: [27]}
# }
# date: {
#     'doc_freq': 1,
#     'docs': {917: [6]}
# }
# vic: {
#     'doc_freq': 2,
#     'docs': {918: [12, 58]}
# }
# firth: {
#     'doc_freq': 2,
#     'docs': {918: [13, 59]}
# }
# steve: {
#     'doc_freq': 1,
#     'docs': {918: [14]}
# }
# gadd: {
#     'doc_freq': 1,
#     'docs': {918: [15]}
# }
# flecks: {
#     'doc_freq': 1,
#     'docs': {918: [28]}
# }
# eraser: {
#     'doc_freq': 1,
#     'docs': {918: [35]}
# }
# rewired: {
#     'doc_freq': 1,
#     'docs': {919: [1]}
# }
# newer: {
#     'doc_freq': 1,
#     'docs': {920: [1]}
# }
# coveted: {
#     'doc_freq': 1,
#     'docs': {920: [5]}
# }
# lm308: {
#     'doc_freq': 1,
#     'docs': {920: [6]}
# }
# tandem: {
#     'doc_freq': 1,
#     'docs': {920: [25]}
# }
# clockwise: {
#     'doc_freq': 1,
#     'docs': {920: [44]}
# }
# piss: {
#     'doc_freq': 2,
#     'docs': {920: [47], 992: [29]}
# }
# smashing: {
#     'doc_freq': 1,
#     'docs': {921: [8]}
# }
# n: {
#     'doc_freq': 1,
#     'docs': {922: [9]}
# }
# raxxess: {
#     'doc_freq': 1,
#     'docs': {922: [16]}
# }
# rax: {
#     'doc_freq': 1,
#     'docs': {922: [17]}
# }
# unitray: {
#     'doc_freq': 1,
#     'docs': {922: [18]}
# }
# universal: {
#     'doc_freq': 1,
#     'docs': {922: [19]}
# }
# tray: {
#     'doc_freq': 2,
#     'docs': {922: [21, 26]}
# }
# uns1: {
#     'doc_freq': 1,
#     'docs': {922: [22]}
# }
# discription: {
#     'doc_freq': 1,
#     'docs': {923: [12]}
# }
# 8516: {
#     'doc_freq': 1,
#     'docs': {923: [17]}
# }
# clearwhite: {
#     'doc_freq': 1,
#     'docs': {923: [30]}
# }
# rhinestone: {
#     'doc_freq': 1,
#     'docs': {923: [31]}
# }
# sigh: {
#     'doc_freq': 1,
#     'docs': {925: [15]}
# }
# warping: {
#     'doc_freq': 1,
#     'docs': {925: [16]}
# }
# electricity: {
#     'doc_freq': 1,
#     'docs': {926: [33]}
# }
# gsr200: {
#     'doc_freq': 1,
#     'docs': {927: [27]}
# }
# 79: {
#     'doc_freq': 1,
#     'docs': {927: [33]}
# }
# 119: {
#     'doc_freq': 1,
#     'docs': {927: [36]}
# }
# gummi: {
#     'doc_freq': 1,
#     'docs': {928: [4]}
# }
# grocery: {
#     'doc_freq': 1,
#     'docs': {928: [11]}
# }
# rectangles: {
#     'doc_freq': 1,
#     'docs': {928: [24]}
# }
# approximately: {
#     'doc_freq': 1,
#     'docs': {928: [25]}
# }
# sink: {
#     'doc_freq': 1,
#     'docs': {928: [61]}
# }
# dish: {
#     'doc_freq': 1,
#     'docs': {928: [62]}
# }
# carabiner: {
#     'doc_freq': 1,
#     'docs': {930: [17]}
# }
# pluged: {
#     'doc_freq': 1,
#     'docs': {931: [12]}
# }
# guitarcable: {
#     'doc_freq': 1,
#     'docs': {931: [16]}
# }
# dissatisfied: {
#     'doc_freq': 1,
#     'docs': {932: [14]}
# }
# craigslist: {
#     'doc_freq': 1,
#     'docs': {932: [23]}
# }
# grimoire: {
#     'doc_freq': 1,
#     'docs': {933: [10]}
# }
# suitcase: {
#     'doc_freq': 1,
#     'docs': {934: [21]}
# }
# vacations: {
#     'doc_freq': 1,
#     'docs': {934: [23]}
# }
# comfort: {
#     'doc_freq': 1,
#     'docs': {934: [29]}
# }
# zelda: {
#     'doc_freq': 2,
#     'docs': {935: [2, 40]}
# }
# authentic: {
#     'doc_freq': 2,
#     'docs': {935: [6, 70]}
# }
# undamaged: {
#     'doc_freq': 1,
#     'docs': {935: [12]}
# }
# displaying: {
#     'doc_freq': 1,
#     'docs': {935: [28]}
# }
# copyrighted: {
#     'doc_freq': 1,
#     'docs': {935: [43]}
# }
# auld: {
#     'doc_freq': 1,
#     'docs': {935: [49]}
# }
# lang: {
#     'doc_freq': 1,
#     'docs': {935: [50]}
# }
# syne: {
#     'doc_freq': 1,
#     'docs': {935: [51]}
# }
# twinkle: {
#     'doc_freq': 2,
#     'docs': {935: [57, 58]}
# }
# mary: {
#     'doc_freq': 1,
#     'docs': {935: [61]}
# }
# lamb: {
#     'doc_freq': 1,
#     'docs': {935: [63]}
# }
# authenticity: {
#     'doc_freq': 1,
#     'docs': {935: [90]}
# }
# complimentary: {
#     'doc_freq': 1,
#     'docs': {935: [116]}
# }
# ohuhu: {
#     'doc_freq': 1,
#     'docs': {935: [117]}
# }
# expressed: {
#     'doc_freq': 1,
#     'docs': {935: [122]}
# }
# cray: {
#     'doc_freq': 1,
#     'docs': {936: [4]}
# }
# 5762: {
#     'doc_freq': 1,
#     'docs': {936: [15]}
# }
# chime: {
#     'doc_freq': 2,
#     'docs': {936: [19], 995: [28]}
# }
# throaty: {
#     'doc_freq': 1,
#     'docs': {936: [20]}
# }
# thud: {
#     'doc_freq': 1,
#     'docs': {936: [24]}
# }
# 63: {
#     'doc_freq': 1,
#     'docs': {936: [27]}
# }
# 250: {
#     'doc_freq': 1,
#     'docs': {936: [34]}
# }
# spoiled: {
#     'doc_freq': 1,
#     'docs': {936: [39]}
# }
# 50stexas: {
#     'doc_freq': 1,
#     'docs': {936: [42]}
# }
# specials: {
#     'doc_freq': 1,
#     'docs': {936: [43]}
# }
# kazoo: {
#     'doc_freq': 1,
#     'docs': {936: [56]}
# }
# 66: {
#     'doc_freq': 1,
#     'docs': {936: [60]}
# }
# epoxy: {
#     'doc_freq': 1,
#     'docs': {937: [41]}
# }
# sharper: {
#     'doc_freq': 2,
#     'docs': {937: [56], 974: [22]}
# }
# chisel: {
#     'doc_freq': 1,
#     'docs': {937: [70]}
# }
# macbook: {
#     'doc_freq': 1,
#     'docs': {938: [5]}
# }
# winter: {
#     'doc_freq': 1,
#     'docs': {938: [8]}
# }
# xlrtrs: {
#     'doc_freq': 1,
#     'docs': {938: [33]}
# }
# sales: {
#     'doc_freq': 1,
#     'docs': {938: [74]}
# }
# motherboard: {
#     'doc_freq': 1,
#     'docs': {941: [4]}
# }
# laid: {
#     'doc_freq': 2,
#     'docs': {941: [5], 961: [50]}
# }
# ti: {
#     'doc_freq': 1,
#     'docs': {941: [9]}
# }
# lm2596: {
#     'doc_freq': 1,
#     'docs': {941: [10]}
# }
# votage: {
#     'doc_freq': 1,
#     'docs': {941: [11]}
# }
# regulator: {
#     'doc_freq': 1,
#     'docs': {941: [12]}
# }
# 200ma: {
#     'doc_freq': 1,
#     'docs': {941: [18]}
# }
# supplies: {
#     'doc_freq': 2,
#     'docs': {941: [23], 956: [15]}
# }
# arturia: {
#     'doc_freq': 1,
#     'docs': {942: [6]}
# }
# microbrute: {
#     'doc_freq': 1,
#     'docs': {942: [7]}
# }
# synth: {
#     'doc_freq': 1,
#     'docs': {942: [9]}
# }
# accurately: {
#     'doc_freq': 1,
#     'docs': {945: [28]}
# }
# repeatedly: {
#     'doc_freq': 1,
#     'docs': {945: [53]}
# }
# bells: {
#     'doc_freq': 2,
#     'docs': {946: [7, 27]}
# }
# hat: {
#     'doc_freq': 1,
#     'docs': {946: [14]}
# }
# fir: {
#     'doc_freq': 1,
#     'docs': {946: [20]}
# }
# ankle: {
#     'doc_freq': 1,
#     'docs': {946: [26]}
# }
# fulltone: {
#     'doc_freq': 1,
#     'docs': {947: [3]}
# }
# ocd: {
#     'doc_freq': 1,
#     'docs': {947: [4]}
# }
# clone: {
#     'doc_freq': 2,
#     'docs': {947: [5, 10]}
# }
# closest: {
#     'doc_freq': 1,
#     'docs': {947: [8]}
# }
# resin: {
#     'doc_freq': 1,
#     'docs': {947: [31]}
# }
# engine: {
#     'doc_freq': 1,
#     'docs': {947: [32]}
# }
# my550: {
#     'doc_freq': 1,
#     'docs': {949: [3]}
# }
# attachment: {
#     'doc_freq': 1,
#     'docs': {949: [6]}
# }
# nady: {
#     'doc_freq': 2,
#     'docs': {949: [11, 21]}
# }
# dmk5: {
#     'doc_freq': 1,
#     'docs': {949: [12]}
# }
# dm70: {
#     'doc_freq': 4,
#     'docs': {949: [22, 33, 59, 81]}
# }
# customersupplied: {
#     'doc_freq': 1,
#     'docs': {949: [27]}
# }
# steadily: {
#     'doc_freq': 1,
#     'docs': {949: [34]}
# }
# assemblies: {
#     'doc_freq': 1,
#     'docs': {949: [47]}
# }
# 6inch: {
#     'doc_freq': 1,
#     'docs': {949: [66]}
# }
# saxophones: {
#     'doc_freq': 1,
#     'docs': {949: [84]}
# }
# dm80: {
#     'doc_freq': 1,
#     'docs': {949: [85]}
# }
# baritones: {
#     'doc_freq': 1,
#     'docs': {949: [86]}
# }
# nano: {
#     'doc_freq': 1,
#     'docs': {951: [16]}
# }
# delayfalloff: {
#     'doc_freq': 1,
#     'docs': {951: [30]}
# }
# burning: {
#     'doc_freq': 1,
#     'docs': {951: [68]}
# }
# vesa: {
#     'doc_freq': 2,
#     'docs': {953: [13, 39]}
# }
# stabilize: {
#     'doc_freq': 2,
#     'docs': {953: [33], 993: [49]}
# }
# 17: {
#     'doc_freq': 2,
#     'docs': {953: [43], 969: [5]}
# }
# mikes: {
#     'doc_freq': 1,
#     'docs': {953: [56]}
# }
# equivalent: {
#     'doc_freq': 1,
#     'docs': {953: [65]}
# }
# halloween: {
#     'doc_freq': 1,
#     'docs': {955: [6]}
# }
# rinse: {
#     'doc_freq': 1,
#     'docs': {955: [11]}
# }
# distilled: {
#     'doc_freq': 1,
#     'docs': {955: [13]}
# }
# steam: {
#     'doc_freq': 1,
#     'docs': {955: [17]}
# }
# dump: {
#     'doc_freq': 1,
#     'docs': {955: [19]}
# }
# juice: {
#     'doc_freq': 1,
#     'docs': {955: [32]}
# }
# pump: {
#     'doc_freq': 1,
#     'docs': {955: [37]}
# }
# gunky: {
#     'doc_freq': 1,
#     'docs': {955: [39]}
# }
# slimpar: {
#     'doc_freq': 1,
#     'docs': {956: [4]}
# }
# 64: {
#     'doc_freq': 1,
#     'docs': {956: [5]}
# }
# rgba: {
#     'doc_freq': 1,
#     'docs': {956: [6]}
# }
# paperwork: {
#     'doc_freq': 1,
#     'docs': {956: [11]}
# }
# misc: {
#     'doc_freq': 1,
#     'docs': {956: [14]}
# }
# velcros: {
#     'doc_freq': 1,
#     'docs': {956: [31]}
# }
# suitable: {
#     'doc_freq': 1,
#     'docs': {959: [4]}
# }
# foldable: {
#     'doc_freq': 1,
#     'docs': {959: [9]}
# }
# stashed: {
#     'doc_freq': 1,
#     'docs': {959: [11]}
# }
# binder: {
#     'doc_freq': 1,
#     'docs': {959: [17]}
# }
# pages: {
#     'doc_freq': 1,
#     'docs': {959: [19]}
# }
# folded: {
#     'doc_freq': 1,
#     'docs': {959: [26]}
# }
# couch: {
#     'doc_freq': 1,
#     'docs': {959: [29]}
# }
# retailer: {
#     'doc_freq': 1,
#     'docs': {961: [5]}
# }
# 150lbs: {
#     'doc_freq': 1,
#     'docs': {961: [15]}
# }
# empty: {
#     'doc_freq': 1,
#     'docs': {961: [16]}
# }
# 5mph: {
#     'doc_freq': 1,
#     'docs': {961: [33]}
# }
# 1164: {
#     'doc_freq': 1,
#     'docs': {962: [15]}
# }
# korn: {
#     'doc_freq': 1,
#     'docs': {962: [31]}
# }
# trivium: {
#     'doc_freq': 1,
#     'docs': {962: [32]}
# }
# peavy: {
#     'doc_freq': 1,
#     'docs': {962: [44]}
# }
# 6505: {
#     'doc_freq': 1,
#     'docs': {962: [45]}
# }
# operating: {
#     'doc_freq': 1,
#     'docs': {963: [13]}
# }
# dreadnought: {
#     'doc_freq': 1,
#     'docs': {966: [15]}
# }
# pentagrams: {
#     'doc_freq': 1,
#     'docs': {967: [2]}
# }
# affordability: {
#     'doc_freq': 1,
#     'docs': {968: [19]}
# }
# pyramids: {
#     'doc_freq': 1,
#     'docs': {969: [9]}
# }
# pyramid: {
#     'doc_freq': 1,
#     'docs': {969: [15]}
# }
# applause: {
#     'doc_freq': 1,
#     'docs': {969: [20]}
# }
# limitation: {
#     'doc_freq': 1,
#     'docs': {969: [26]}
# }
# distance: {
#     'doc_freq': 1,
#     'docs': {969: [33]}
# }
# bulbs: {
#     'doc_freq': 1,
#     'docs': {969: [38]}
# }
# repertoire: {
#     'doc_freq': 1,
#     'docs': {973: [6]}
# }
# gadgets: {
#     'doc_freq': 1,
#     'docs': {973: [7]}
# }
# needless: {
#     'doc_freq': 1,
#     'docs': {973: [24]}
# }
# patent: {
#     'doc_freq': 1,
#     'docs': {973: [42]}
# }
# pending: {
#     'doc_freq': 1,
#     'docs': {973: [43]}
# }
# mahalo: {
#     'doc_freq': 1,
#     'docs': {974: [3]}
# }
# mahalos: {
#     'doc_freq': 2,
#     'docs': {974: [9, 29]}
# }
# meaning: {
#     'doc_freq': 1,
#     'docs': {974: [16]}
# }
# favor: {
#     'doc_freq': 1,
#     'docs': {975: [17]}
# }
# spirits: {
#     'doc_freq': 1,
#     'docs': {975: [22]}
# }
# overheads: {
#     'doc_freq': 1,
#     'docs': {975: [24]}
# }
# meteor: {
#     'doc_freq': 1,
#     'docs': {976: [3]}
# }
# h2n: {
#     'doc_freq': 1,
#     'docs': {976: [10]}
# }
# msh6: {
#     'doc_freq': 1,
#     'docs': {976: [22]}
# }
# capsule: {
#     'doc_freq': 1,
#     'docs': {976: [24]}
# }
# daphne: {
#     'doc_freq': 2,
#     'docs': {978: [13, 19]}
# }
# sweetest: {
#     'doc_freq': 1,
#     'docs': {978: [21]}
# }
# mild: {
#     'doc_freq': 1,
#     'docs': {978: [32]}
# }
# mades: {
#     'doc_freq': 1,
#     'docs': {978: [43]}
# }
# 9500: {
#     'doc_freq': 1,
#     'docs': {979: [12]}
# }
# bong: {
#     'doc_freq': 1,
#     'docs': {979: [51]}
# }
# bop: {
#     'doc_freq': 1,
#     'docs': {979: [53]}
# }
# fave: {
#     'doc_freq': 1,
#     'docs': {980: [2]}
# }
# jazzmaster: {
#     'doc_freq': 1,
#     'docs': {980: [6]}
# }
# offsets: {
#     'doc_freq': 1,
#     'docs': {980: [8]}
# }
# flats: {
#     'doc_freq': 1,
#     'docs': {980: [13]}
# }
# dullplucky: {
#     'doc_freq': 1,
#     'docs': {980: [16]}
# }
# liveliness: {
#     'doc_freq': 1,
#     'docs': {980: [24]}
# }
# throughout: {
#     'doc_freq': 1,
#     'docs': {980: [28]}
# }
# wounded: {
#     'doc_freq': 1,
#     'docs': {980: [40]}
# }
# gk2110: {
#     'doc_freq': 1,
#     'docs': {981: [3]}
# }
# rc300: {
#     'doc_freq': 1,
#     'docs': {981: [5]}
# }
# sewcreate: {
#     'doc_freq': 1,
#     'docs': {981: [57]}
# }
# akai: {
#     'doc_freq': 2,
#     'docs': {981: [61, 78]}
# }
# miniak: {
#     'doc_freq': 2,
#     'docs': {981: [63, 79]}
# }
# virtual: {
#     'doc_freq': 1,
#     'docs': {981: [64]}
# }
# synthesizer: {
#     'doc_freq': 1,
#     'docs': {981: [66]}
# }
# vocoder: {
#     'doc_freq': 1,
#     'docs': {981: [67]}
# }
# viewing: {
#     'doc_freq': 1,
#     'docs': {981: [77]}
# }
# borrow: {
#     'doc_freq': 1,
#     'docs': {983: [21]}
# }
# ruler: {
#     'doc_freq': 1,
#     'docs': {985: [11]}
# }
# 116: {
#     'doc_freq': 2,
#     'docs': {985: [12], 992: [18]}
# }
# drillbit: {
#     'doc_freq': 1,
#     'docs': {985: [13]}
# }
# 650mm: {
#     'doc_freq': 1,
#     'docs': {986: [3]}
# }
# luggage: {
#     'doc_freq': 1,
#     'docs': {986: [36]}
# }
# sixth: {
#     'doc_freq': 1,
#     'docs': {986: [38]}
# }
# cuts: {
#     'doc_freq': 1,
#     'docs': {987: [1]}
# }
# policy: {
#     'doc_freq': 1,
#     'docs': {988: [13]}
# }
# m238: {
#     'doc_freq': 1,
#     'docs': {988: [19]}
# }
# chaining: {
#     'doc_freq': 1,
#     'docs': {988: [27]}
# }
# sockets: {
#     'doc_freq': 1,
#     'docs': {988: [35]}
# }
# trustworthy: {
#     'doc_freq': 1,
#     'docs': {989: [28]}
# }
# dimebag: {
#     'doc_freq': 1,
#     'docs': {989: [34]}
# }
# explorer: {
#     'doc_freq': 1,
#     'docs': {989: [37]}
# }
# rk: {
#     'doc_freq': 1,
#     'docs': {990: [20]}
# }
# rimhead: {
#     'doc_freq': 1,
#     'docs': {991: [31]}
# }
# perpose: {
#     'doc_freq': 1,
#     'docs': {991: [39]}
# }
# topload: {
#     'doc_freq': 1,
#     'docs': {992: [22]}
# }
# fed: {
#     'doc_freq': 1,
#     'docs': {992: [28]}
# }
# purists: {
#     'doc_freq': 1,
#     'docs': {992: [30]}
# }
# graph: {
#     'doc_freq': 1,
#     'docs': {992: [38]}
# }
# saddles: {
#     'doc_freq': 1,
#     'docs': {992: [40]}
# }
# injection: {
#     'doc_freq': 1,
#     'docs': {992: [45]}
# }
# mold: {
#     'doc_freq': 1,
#     'docs': {992: [46]}
# }
# believer: {
#     'doc_freq': 1,
#     'docs': {992: [53]}
# }
# graphite: {
#     'doc_freq': 1,
#     'docs': {992: [56]}
# }
# breakangles: {
#     'doc_freq': 1,
#     'docs': {992: [58]}
# }
# fallout: {
#     'doc_freq': 1,
#     'docs': {993: [38]}
# }
# report: {
#     'doc_freq': 1,
#     'docs': {993: [48]}
# }
# sh: {
#     'doc_freq': 1,
#     'docs': {993: [55]}
# }
# wedding: {
#     'doc_freq': 1,
#     'docs': {994: [2]}
# }
# buffing: {
#     'doc_freq': 1,
#     'docs': {994: [41]}
# }
# blocks: {
#     'doc_freq': 1,
#     'docs': {994: [42]}
# }
# naturally: {
#     'doc_freq': 1,
#     'docs': {994: [44]}
# }
# looser: {
#     'doc_freq': 1,
#     'docs': {994: [67]}
# }
# elenco: {
#     'doc_freq': 1,
#     'docs': {995: [3]}
# }
# st12: {
#     'doc_freq': 1,
#     'docs': {995: [5]}
# }
# growl: {
#     'doc_freq': 1,
#     'docs': {995: [24]}
# }
# farty: {
#     'doc_freq': 1,
#     'docs': {995: [49]}
# }
# ranging: {
#     'doc_freq': 1,
#     'docs': {995: [58]}
# }
# jeff: {
#     'doc_freq': 1,
#     'docs': {995: [59]}
# }
# beck: {
#     'doc_freq': 1,
#     'docs': {995: [60]}
# }
# yngwie: {
#     'doc_freq': 1,
#     'docs': {995: [62]}
# }
# neoclassical: {
#     'doc_freq': 1,
#     'docs': {995: [63]}
# }
# john: {
#     'doc_freq': 1,
#     'docs': {995: [64]}
# }
# mayer: {
#     'doc_freq': 1,
#     'docs': {995: [65]}
# }
# importantly: {
#     'doc_freq': 1,
#     'docs': {995: [72]}
# }
# toneprint: {
#     'doc_freq': 1,
#     'docs': {997: [9]}
# }
# artists: {
#     'doc_freq': 1,
#     'docs': {997: [15]}
# }
# stringthru: {
#     'doc_freq': 2,
#     'docs': {998: [32, 48]}
# }
# stopflair: {
#     'doc_freq': 1,
#     'docs': {998: [39]}
# }
# biggie: {
#     'doc_freq': 1,
#     'docs': {998: [50]}
# }
# according: {
#     'doc_freq': 1,
#     'docs': {999: [13]}
# }
# screenshot: {
#     'doc_freq': 1,
#     'docs': {999: [16]}
# }
# amazoncom: {
#     'doc_freq': 1,
#     'docs': {999: [21]}
# }
# pity: {
#     'doc_freq': 1,
#     'docs': {999: [22]}
# }

# %%
print(len(positional_index))
# Out:
# 6471

# %%
file_path = "/content/drive/MyDrive/positional_index.pkl"

# %%
def dump_positional_index(file_path, positional_index):
    with open(file_path, "wb") as file_obj:
        pickle.dump(positional_index, file_obj)

# Dumping
dump_positional_index(file_path, positional_index)

# %%
def load_positional_index(file_path):
    with open(file_path, "rb") as file_obj:
        loaded_inverted_index = pickle.load(file_obj)
    return loaded_inverted_index

# Loading
positional_index = load_positional_index(file_path)

# %% [markdown]
# **QUERY HANDALING**

# %%
def preprocess(text):
    lem = WordNetLemmatizer()
    text = text.lower()
    text = re.sub('[^A-Z a-z ]+', ' ', text)
    text = text.split()
    tokens = []
    for j in text :
        tokens.append(j)
    stop_words = set(stopwords.words("english"))
    tokens = [token for token in tokens if token not in stop_words and token not in string.punctuation]
    tokens = [token for token in tokens if token.strip()]
    tokens = [lem.lemmatize(token) for token in tokens]
    tokens = ' '.join(tokens)
    return tokens

# %%
def retrieve_documents(queries, positional_index):
    results = []
    error_messages = []

    for query in queries:
        processed_query = preprocess(query)
        terms = processed_query.split(' ')

        if len(terms) > 5:
            error_messages.append(f"Length of the input sequence of query '{query}' is >5.")
            continue

        last_index = positional_index[terms[0]]['docs']
        for i in range(1, len(terms)):
            new_term = terms[i]
            if new_term not in positional_index:
                error_messages.append(f"Word '{new_term}' not in dictionary for query '{query}'!")
                break
            new_last_index = {}
            for fid in last_index:
                if fid in positional_index[new_term]['docs']:
                    found = []
                    for old_position in last_index[fid]:
                        for new_position in positional_index[new_term]['docs'][fid]:
                            if new_position == (old_position + 1):
                                found.append(old_position)
                    if len(found):
                        new_last_index[fid] = found
            last_index = new_last_index
        documents_found = list(last_index.keys())
        results.append(documents_found)

    return results, error_messages

# %% [markdown]
# **USER QUERY INPUT**

# %%
n = int(input())
queries = [input().strip() for _ in range(n)]

query_results, error_messages = retrieve_documents(queries, positional_index)

for i, result in enumerate(query_results, start=1):
    print(f"Number of documents retrieved for query {i} using positional index: {len(result)}")
    if result:
        filenames = [f"file{value}.txt" for value in result]
        print(f"Names of documents retrieved for query {i} using positional index: ", end="")
        print(*filenames, sep=", ")
    else:
        print("No documents found.")

for error_message in error_messages:
    print(error_message)
# Out:
# 1
# great is value
# Number of documents retrieved for query 1 using positional index: 10
# Names of documents retrieved for query 1 using positional index: file65.txt, file103.txt, file330.txt, file466.txt, file597.txt, file748.txt, file767.txt, file789.txt, file899.txt, file993.txt
